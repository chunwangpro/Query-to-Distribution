# %%
# %load LatticeCopula_legacy.py
import argparse
import sys

import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_lattice as tfl
from matplotlib import pyplot as plt
from pyDOE import lhs
from tqdm import tqdm, trange

import common
import datasets
import estimators as estimators_lib


def Oracle(table, query):
    cols, idxs, ops, vals = query
    oracle_est = estimators_lib.Oracle(table)
    return oracle_est.Query(cols, ops, vals)


def cal_true_card(query, table):
    cols, idxs, ops, vals = query
    ops = np.array(ops)
    probs = Oracle(table, (cols, idxs, ops, vals))
    return probs


def GenerateQuery(table, min_num_filters, max_num_filters, rng, dataset):
    """Generate a random query."""
    num_filters = rng.randint(max_num_filters - 1, max_num_filters)
    cols, idxs, ops, vals = SampleTupleThenRandom(table, num_filters, rng, dataset)
    sel = cal_true_card((cols, idxs, ops, vals), table) / float(table.cardinality)
    return cols, idxs, ops, vals, sel


def SampleTupleThenRandom(table, num_filters, rng, dataset):
    vals = []
    new_table = table.data
    s = new_table.iloc[rng.randint(0, new_table.shape[0])]
    vals = s.values

    idxs = rng.choice(len(table.columns), replace=False, size=num_filters)
    cols = np.take(table.columns, idxs)
    # If dom size >= 10, okay to place a range filter.
    # Otherwise, low domain size columns should be queried with equality.
    # ops = rng.choice(['='], size=num_filters)
    # ops = rng.choice(['<=', '>=', '>', '<'], size=num_filters)
    # ops = rng.choice(['<=', '>='], size=num_filters)
    ops = rng.choice(["<="], size=num_filters)
    # ops_all_eqs = ['='] * num_filters
    # sensible_to_do_range = [c.DistributionSize() >= 10 for c in cols]
    # ops = np.where(sensible_to_do_range, ops, ops_all_eqs)
    # if num_filters == len(table.columns):
    #     return table.columns,np.arange(len(table.columns)), ops, vals
    vals = vals[idxs]
    op_a = []
    val_a = []
    for i in range(len(vals)):
        val_a.append([vals[i]])
        op_a.append([ops[i]])
    return cols, idxs, pd.DataFrame(op_a).values, pd.DataFrame(val_a).values


def dictionary_column_interval(table_size, query_set):
    # Traverse all queries to apply the intervalization skill for each column
    # deal with columns with all positive values
    n_column = table_size[1]
    column_interval = {}
    for i in range(n_column):
        column_interval[i] = set()
    for query in query_set:
        _, col_idxs, _, vals, _ = query
        for i in range(len(col_idxs)):
            column_interval[col_idxs[i]].add(vals[i][0])
    for k, v in column_interval.items():
        column_interval[k] = sorted(list(v))
        least, great = column_interval[k][0], column_interval[k][-1]
        column_interval[k] = sorted([0, least / 2] + column_interval[k] + [great + 1])
    return column_interval


def count_column_unique_interval(unique_intervals):
    # count unique query interval in each column
    return [len(v) for v in unique_intervals.values()]


def process_train_data(unique_intervals, query_set, train_size=1):
    train_size = 1
    X, Y = [], []
    origin = np.array([[0, v[-1]] for v in unique_intervals.values()]).ravel()
    for query in query_set:
        x = list(origin)
        _, col_idxs, ops, vals, sel = query
        for i in range(len(col_idxs)):
            if ops[i][0] == "<=":
                x[col_idxs[i] * 2 + 1] = vals[i][0]
            elif ops[i][0] == "<":
                ind = unique_intervals[col_idxs[i]].index(vals[i][0]) - 1
                x[col_idxs[i] * 2 + 1] = unique_intervals[col_idxs[i]][ind]
            elif ops[i][0] == ">":
                x[col_idxs[i] * 2] = vals[i][0]
            elif ops[i][0] == ">=":
                ind = unique_intervals[col_idxs[i]].index(vals[i][0]) + 1
                x[col_idxs[i] * 2] = unique_intervals[col_idxs[i]][ind]
            elif ops[i][0] == "=":
                ind = unique_intervals[col_idxs[i]].index(vals[i][0]) - 1
                x[col_idxs[i] * 2] = unique_intervals[col_idxs[i]][ind]
                x[col_idxs[i] * 2 + 1] = vals[i][0]
        X.append(x)
        Y.append(sel)
    X = np.array(X).astype(np.float32)
    Y = np.array(Y).astype(np.float32).reshape(-1, 1)
    total = np.concatenate((X, Y), axis=1)
    # total = np.unique(total, axis=0)
    #     choose = np.random.choice(total.shape[0], size=round(total.shape[0]*train_size), replace=False)
    #     others = list(set(range(total.shape[0])) - set(choose))
    #     train, test = total[choose], total[others]
    #     df_train = pd.DataFrame(train, columns=[f'col_{i}' for i in range(total.shape[1])])
    df_train = pd.DataFrame(total, columns=[f"col_{i}" for i in range(total.shape[1])])
    # boundary
    df_train.loc[len(df_train.index)] = [0] * total.shape[1]
    zero = [[v[-1], 0] for v in unique_intervals.values()]
    df_train.loc[len(df_train.index)] = list(np.array(zero).ravel()) + [0.0]
    one = [[0, v[-1]] for v in unique_intervals.values()]
    df_train.loc[len(df_train.index)] = list(np.array(one).ravel()) + [1.0]

    new_train = np.array(df_train.sort_values(by=list(df_train.columns)[:-1]))
    train_X, train_Y = np.hsplit(new_train, [-1])

    #     df_test = pd.DataFrame(test, columns=[f'col_{i}' for i in range(total.shape[1])])
    #     new_test = np.array(df_test.sort_values(by=list(df_test.columns)[:-1]))
    #     test_X, test_Y = np.hsplit(new_test, [-1])
    return train_X, train_Y  # , test_X, test_Y


def generate_data_new(grid, model):
    assert grid.shape[1] == n_column
    # transform 1-input grid to 2-input extend grid
    length = grid.shape[0]
    inf = [0] * length
    grid_dict = {}
    for i in range(n_column):
        grid_dict[f"col_{i}_inf"] = inf
        grid_dict[f"col_{i}_sup"] = grid[:, i]
    extend_grid = np.array(pd.DataFrame(grid_dict))
    print("Begin model inference")
    pred = model.inference(extend_grid)
    print("Done")
    # newpred is the predict cardinality
    newpred = np.round(pred * n_row)
    # newpred = np.round(pred)
    # delete all the zero cardinality rows
    line = pd.DataFrame(
        np.concatenate([grid, newpred], axis=1),
        columns=[f"col_{i}" for i in range(n_column)] + ["card"],
    )
    nozero = (line == 0).sum(axis=1)
    line = line[nozero == 0].reset_index(drop=True)
    grid, pred = np.hsplit(np.array(line), [-1])
    pred = pred.astype(int)
    # generate dataNew
    print("\nBegin generating table...")
    dataNew = pd.DataFrame(columns=[f"col_{i}" for i in range(n_column)], index=range(n_row))
    count = 0
    for i in trange(grid.shape[0]):
        df = dataNew
        grid_value = grid[i]
        for j in range(n_column):
            df = df.query(f"col_{j} <= {grid_value[j]}")
        card = pred[i][0] - df.shape[0]
        if card > 0:
            # df3 = pd.DataFrame({f"col_{k}": [grid_value[k]] * card for k in range(n_column)})
            # dataNew = dataNew.append(df3, ignore_index = True)
            dataNew.iloc[count : count + card, :] = grid_value
            count += card
            if count > n_row:
                print("Reached table length in ", i, grid.shape[0])
                break
        # print table length every 5000
        if i % 5000 == 0:
            print(count)
    dataNew.dropna(axis=0, how="all", inplace=True)
    return dataNew


def execute_query(dataNew, query_set):
    diff = []
    for query in tqdm(query_set):
        df = dataNew
        _, col_idxs, ops, vals, sel = query
        for i in range(len(col_idxs)):
            op = "==" if ops[i][0] == "=" else ops[i][0]
            df = df.query(f"col_{col_idxs[i]} {op} {vals[i][0]}")
        card = 1 if round(sel * n_row) == 0 else round(sel * n_row)
        card2 = 1 if df.shape[0] == 0 else df.shape[0]
        diff.append(max(card / card2, card2 / card))
    return diff


def print_error(diff, args):
    print(
        f"\n\n Q-error of Lattice (query size={args.query_size}, condition={args.num_conditions}, epoches={args.epochs}):\n"
    )
    print(f"min:    {np.min(diff)}")
    print(f"10:     {np.percentile(diff, 10)}")
    print(f"20:     {np.percentile(diff, 20)}")
    print(f"30:     {np.percentile(diff, 30)}")
    print(f"40:     {np.percentile(diff, 40)}")
    print(f"median: {np.median(diff)}")
    print(f"60:     {np.percentile(diff, 60)}")
    print(f"70:     {np.percentile(diff, 70)}")
    print(f"80:     {np.percentile(diff, 80)}")
    print(f"90:     {np.percentile(diff, 90)}")
    print(f"95:     {np.percentile(diff, 95)}")
    print(f"max:    {np.max(diff)}")
    print(f"mean:   {np.mean(diff)}")


class LatticeCDFLayer(tf.keras.Model):
    def __init__(self, dim, lattice_size=2):
        super().__init__()
        self.dim = dim
        self.lattice_size = lattice_size

        self.copula_lattice = tfl.layers.Lattice(
            lattice_sizes=[self.lattice_size] * self.dim,
            interpolation="hypercube",  # simplex
            monotonicities=["increasing"] * self.dim,
            output_min=0.0,
            output_max=1.0,
            name="lattice",
        )

    def call(self, x):
        y = self.copula_lattice(x)
        grad = y
        for i in range(self.dim):
            grad = tf.gradients(grad, x[i])  # , stop_gradients=[a, b])
        return y, x, grad


class CopulaModel(LatticeCDFLayer):
    def __init__(self, dim, lattice_size=2, pwl_keypoints=None):
        super().__init__(dim=dim, lattice_size=lattice_size)
        self.pwl_calibration_input_keypoints = (
            unique_intervals if pwl_keypoints is None else pwl_keypoints
        )

        self.model_inputs = []
        for i in range(self.dim):
            self.model_inputs.append(tf.keras.layers.Input(shape=[1], name="col_%s_inf" % i))
            self.model_inputs.append(tf.keras.layers.Input(shape=[1], name="col_%s_sup" % i))

        self.calibrators = []
        for i in range(self.dim):
            self.calibrators.append(
                tfl.layers.PWLCalibration(
                    input_keypoints=np.array(self.pwl_calibration_input_keypoints[i]),
                    dtype=tf.float32,
                    output_min=0.0,
                    output_max=1.0,
                    clamp_min=True,
                    clamp_max=True,
                    monotonicity="decreasing",
                    name="col_%s_inf_pwl" % i,
                )(self.model_inputs[2 * i])
            )
            self.calibrators.append(
                tfl.layers.PWLCalibration(
                    input_keypoints=np.array(self.pwl_calibration_input_keypoints[i]),
                    # input_keypoints=np.linspace(
                    #     feat_mins[i],
                    #     feat_maxs[i],
                    #     num=pwl_calibration_num_keypoints),
                    dtype=tf.float32,
                    output_min=0.0,
                    output_max=1.0,
                    clamp_min=True,
                    clamp_max=True,
                    monotonicity="increasing",
                    name="col_%s_sup_pwl" % i,
                )(self.model_inputs[2 * i + 1])
            )

        self.lattice_cdf = []
        for i in range(self.dim):
            self.lattice_cdf.append(
                tfl.layers.Lattice(
                    lattice_sizes=[lattice_size] * 2,
                    interpolation="hypercube",  # simplex
                    monotonicities=["increasing"] * 2,
                    output_min=0.0,
                    output_max=1.0,
                    name="lattice_col_%s" % i,
                )([self.calibrators[2 * i], self.calibrators[2 * i + 1]])
            )

        self.model = tf.keras.models.Model(
            inputs=self.model_inputs, outputs=self.copula_lattice(self.lattice_cdf)
        )

    def train_step(self, data):
        x, y = data
        with tf.GradientTape() as tape:
            y_pred, lattice_inputs, lattice_grad = self(x, training=True)  # , training=True)
            loss1 = self.compiled_loss(y, y_pred)
            loss2 = 100000  # min(x)
            loss3 = 1  # max(sum(x)-self.dim+1, 0)
            loss4 = 1
            loss = loss1 + loss2 + loss3 + loss4
        trainable_vars = self.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))
        self.compiled_metrics.update_state(y, y_pred)
        return {m.name: m.result() for m in self.metrics}


# loss 可以在complie里传入，但是不能通过重写fit方法来载入


class Trainer_Lattice(CopulaModel):
    def __init__(
        self, name, dim, pwl_keypoints=None, lattice_size=2  # also can input table unique values
    ):
        super().__init__(dim=dim, lattice_size=lattice_size)
        self.model_path = "./models/Lattice/model/" + name
        self.weight_path = "./models/Lattice/weight/" + name
        self.model.save("%s.hdf5" % self.model_path)
        self.model.summary()

    def fit(
        self,
        X,
        y,
        lr=0.01,
        bs=1000,
        epochs=1000,
        reduceLR_factor=0.1,
        reduceLR_patience=10,
        ESt_patience=20,
        verbose=1,
        loss="MSE",
        opt="Adam",
    ):
        assert X.shape[0] == y.shape[0]

        X = X.astype(np.float32)
        y = y.astype(np.float32)

        features = [X[:, i] for i in range(X.shape[1])]
        target = y

        Loss = {
            "MAE": tf.keras.losses.mean_absolute_error,
            "MSE": tf.keras.losses.mean_squared_error,
            "MAPE": tf.keras.losses.mean_absolute_percentage_error,
        }

        Opt = {
            "Adam": tf.keras.optimizers.Adam(lr),
            "Nadam": tf.keras.optimizers.Nadam(),
            "Adagrad": tf.keras.optimizers.Adagrad(),
            "Adadelta": tf.keras.optimizers.Adadelta(),
            "Adamax": tf.keras.optimizers.Adamax(),
            "RMSprop": tf.keras.optimizers.RMSprop(),
        }

        self.model.compile(loss=Loss[loss], optimizer=Opt[opt])

        earlyStopping = tf.keras.callbacks.EarlyStopping(
            restore_best_weights=True,
            monitor="loss",
            mode="min",
            patience=ESt_patience,
            verbose=verbose,
        )
        mcp_save = tf.keras.callbacks.ModelCheckpoint(
            filepath=f"{self.weight_path}.h5",
            save_weights_only=True,
            save_best_only=True,
            monitor="loss",
            mode="min",
            verbose=verbose,
        )
        reduce_lr_loss = tf.keras.callbacks.ReduceLROnPlateau(
            monitor="loss",
            factor=reduceLR_factor,
            patience=reduceLR_patience,
            verbose=verbose,
            min_delta=1e-8,
            mode="min",
        )

        self.model.fit(
            features,
            target,
            epochs=epochs,
            batch_size=bs,
            verbose=1,
            callbacks=[earlyStopping, mcp_save, reduce_lr_loss],
        )

    def load(self):
        self.model = tf.keras.models.load_model("%s.hdf5" % self.model_path)
        self.model.load_weights("%s.hdf5" % self.weight_path)

    def inference(self, grid):
        # assert grid.shape[1] == self.dim * 2
        pred = self.model.predict(np.hsplit(grid, self.dim * 2))
        return pred


if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    parser.add_argument("--dataset", type=str, default="wine3", help="Dataset.")
    parser.add_argument("--loss", type=str, default="MSE", help="Loss.")
    parser.add_argument("--opt", type=str, default="Adam", help="Optimizer.")
    parser.add_argument("--query-size", type=int, default=1000, help="query size")
    parser.add_argument("--num-conditions", type=int, default=2, help="num of conditions")
    parser.add_argument("--epochs", type=int, default=1000, help="Number of epochs to train for.")
    parser.add_argument(
        "--lhs_n", type=int, default=10000, help="Number of lhs samples to generate for."
    )
    parser.add_argument("--train-size", type=float, default=0.8, help="train size")
    parser.add_argument("--bs", type=int, default=1000, help="Batch size.")
    parser.add_argument("--lr", type=float, default=1e-2, help="learning rate")
    parser.add_argument("--lattice", type=int, default=2, help="Lattice size.")
    parser.add_argument("--seed", type=int, default=4321, help="Random seed")
    parser.add_argument("--sample", type=int, default=0, help="reload trained mode")
    try:
        args = parser.parse_args()
    except:
        args, unknown = parser.parse_known_args()
    bs = int(args.bs)
    lr = float(args.lr)
    train_size = float(args.train_size)
    epochs = int(args.epochs)
    lattice = int(args.lattice)
    sample = int(args.sample)
    lhs_n = int(args.lhs_n)

    table = datasets.LoadDataset(args.dataset + ".csv", args.dataset)

    print("Begin Generating Queries ...")
    rng = np.random.RandomState(args.seed)
    query_set = [
        GenerateQuery(table, 2, args.num_conditions + 1, rng, args.dataset)
        for i in trange(args.query_size)
    ]
    print("Complete Generating Queries.")

    print("\n\nCalculating intervalization...")
    table_size = table.data.shape
    n_row, n_column = table_size[0], table_size[1]
    unique_intervals = dictionary_column_interval(table_size, query_set)
    column_interval_number = count_column_unique_interval(unique_intervals)
    print("\nColumn intervals", column_interval_number, np.product(column_interval_number))

    print("\n\nBuilding Lattice...")
    train_X, train_Y = process_train_data(unique_intervals, query_set)
    # train_X, train_Y, test_X, test_Y = process_train_data(unique_intervals, query_set)
    # print("  Total query:", args.query_size)
    # print("  Train query:", train_X.shape[0])
    # print("  Test  query:", test_X.shape[0])
    # print("\n\n")
    name = f"{args.dataset}_{args.query_size}query_{args.num_conditions}column_{args.epochs}epoch"
    # model = LatticeCDF(unique_intervals, pwl_keypoints=None)
    m = Trainer_Lattice(name, n_column, pwl_keypoints=None)
    print("Done.")

    print("\n\nBegin training...\n")
    m.fit(train_X, train_Y, lr=lr, bs=bs, epochs=epochs, loss=args.loss, opt=args.opt)

    print("\nFinish training")
    # Full-Factorial net of unique intervals
    #     values = [v for v in unique_intervals.values()]
    #     mesh = np.meshgrid(*values)
    #     grid = np.array(mesh).T.reshape(-1, len(values)).astype(np.float32)

    # Latin Hypercube sampling
    #     lb = np.array([v[1] for v in unique_intervals.values()])
    #     ub = np.array([v[-1] for v in unique_intervals.values()])
    #     lhs_sample = lhs(n_column, samples=10000, criterion='center')
    #     sample_df = pd.DataFrame(lb + (ub-lb)*lhs_sample, columns=[f'col_{i}' for i in range(n_column)])
    #     grid = np.array(sample_df.sort_values(by=list(sample_df.columns)))
    lb = np.array([1] * n_column)
    ub = np.array(column_interval_number) - 1
    lhs_sample = lb + (ub - lb) * lhs(n_column, samples=lhs_n, criterion="center")
    index = np.round(lhs_sample).astype(int)
    grid_mesh = np.empty_like(index, dtype=np.float32)
    for i in range(lhs_n):
        idx = index[i, :]
        grid_mesh[i] = [unique_intervals[j][idx[j]] for j in range(n_column)]
    sample_df = pd.DataFrame(grid_mesh, columns=[f"col_{i}" for i in range(n_column)])
    grid_a = np.array(sample_df.sort_values(by=list(sample_df.columns)))
    greatest = np.array([v[-1] for v in unique_intervals.values()]).reshape(1, -1)
    grid = np.concatenate([grid_a, greatest], axis=0)
    dataNew = generate_data_new(grid, model=m)

    print("\nFinish generate table, calculating Q-error on new table...")
    diff = execute_query(dataNew, query_set)
    print_error(diff, args)

    print(f"\noriginal table shape: {table_size}")
    print(f"  Our table shape   : {dataNew.shape}")
# Out:
# /var/folders/x9/rlw36ttd3d9dvskjy8fd9t3r0000gn/T/ipykernel_3211/4166495890.py:6: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# usage: ipykernel_launcher.py [-h] [--dataset DATASET] [--loss LOSS]
#                              [--opt OPT] [--query-size QUERY_SIZE]
#                              [--num-conditions NUM_CONDITIONS]
#                              [--epochs EPOCHS] [--lhs_n LHS_N]
#                              [--train-size TRAIN_SIZE] [--bs BS] [--lr LR]
#                              [--lattice LATTICE] [--seed SEED]
#                              [--sample SAMPLE]
# ipykernel_launcher.py: error: unrecognized arguments: --f=/Users/chun/Library/Jupyter/runtime/kernel-v2-812950omKv4YarxxJ.json
# load dataset wine3.csv done
# (6497, 3)
# (6497, 3)
# 0
# 1
# 2
# 0 106
# 1 187
# 2 89
# Begin Generating Queries ...
# 100%|██████████| 1000/1000 [00:00<00:00, 4424.56it/s]
# 2024-06-15 04:28:40.203959: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2024-06-15 04:28:40.203991: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-06-15 04:28:40.204001: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-06-15 04:28:40.204057: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-06-15 04:28:40.204077: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Complete Generating Queries.
#
#
# Calculating intervalization...
#
# Column intervals [76, 88, 76] 508288
#
#
# Building Lattice...
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  col_0_inf (InputLayer)      [(None, 1)]                  0         []
#
#  col_0_sup (InputLayer)      [(None, 1)]                  0         []
#
#  col_1_inf (InputLayer)      [(None, 1)]                  0         []
#
#  col_1_sup (InputLayer)      [(None, 1)]                  0         []
#
#  col_2_inf (InputLayer)      [(None, 1)]                  0         []
#
#  col_2_sup (InputLayer)      [(None, 1)]                  0         []
#
#  col_0_inf_pwl (PWLCalibrat  (None, 1)                    76        ['col_0_inf[0][0]']
#  ion)
#
#  col_0_sup_pwl (PWLCalibrat  (None, 1)                    76        ['col_0_sup[0][0]']
#  ion)
#
#  col_1_inf_pwl (PWLCalibrat  (None, 1)                    88        ['col_1_inf[0][0]']
#  ion)
#
#  col_1_sup_pwl (PWLCalibrat  (None, 1)                    88        ['col_1_sup[0][0]']
#  ion)
#
#  col_2_inf_pwl (PWLCalibrat  (None, 1)                    76        ['col_2_inf[0][0]']
#  ion)
#
#  col_2_sup_pwl (PWLCalibrat  (None, 1)                    76        ['col_2_sup[0][0]']
#  ion)
#
#  lattice_col_0 (Lattice)     (None, 1)                    4         ['col_0_inf_pwl[0][0]',
#                                                                      'col_0_sup_pwl[0][0]']
#
#  lattice_col_1 (Lattice)     (None, 1)                    4         ['col_1_inf_pwl[0][0]',
#                                                                      'col_1_sup_pwl[0][0]']
#
#  lattice_col_2 (Lattice)     (None, 1)                    4         ['col_2_inf_pwl[0][0]',
#                                                                      'col_2_sup_pwl[0][0]']
#
#  lattice (Lattice)           (None, 1)                    8         ['lattice_col_0[0][0]',
#                                                                      'lattice_col_1[0][0]',
#                                                                      'lattice_col_2[0][0]']
#
# ==================================================================================================
# Total params: 500 (1.95 KB)
# Trainable params: 500 (1.95 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# /opt/homebrew/Caskroom/miniforge/base/envs/lattice/lib/python3.9/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Nadam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Nadam`.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adagrad` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adagrad`.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adadelta` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adadelta`.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.RMSprop` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.RMSprop`.
# Done.
#
#
# Begin training...
#
# Epoch 1/1000
# 2024-06-15 04:28:42.972152: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 2024-06-15 04:28:43.120594: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node Adam/AssignAddVariableOp.
# 2/2 [==============================] - ETA: 0s - loss: 0.3142
# Epoch 1: loss improved from inf to 0.31416, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 3s 536ms/step - loss: 0.3142 - lr: 0.0100
# Epoch 2/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.2807
# Epoch 2: loss improved from 0.31416 to 0.28074, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 105ms/step - loss: 0.2807 - lr: 0.0100
# Epoch 3/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.2448
# Epoch 3: loss improved from 0.28074 to 0.24481, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 96ms/step - loss: 0.2448 - lr: 0.0100
# Epoch 4/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.2019
# Epoch 4: loss improved from 0.24481 to 0.20192, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 115ms/step - loss: 0.2019 - lr: 0.0100
# Epoch 5/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.1614
# Epoch 5: loss improved from 0.20192 to 0.16145, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 112ms/step - loss: 0.1614 - lr: 0.0100
# Epoch 6/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.1373
# Epoch 6: loss improved from 0.16145 to 0.13726, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 107ms/step - loss: 0.1373 - lr: 0.0100
# Epoch 7/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.1166
# Epoch 7: loss improved from 0.13726 to 0.11660, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 107ms/step - loss: 0.1166 - lr: 0.0100
# Epoch 8/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0991
# Epoch 8: loss improved from 0.11660 to 0.09907, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0991 - lr: 0.0100
# Epoch 9/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0839
# Epoch 9: loss improved from 0.09907 to 0.08391, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0839 - lr: 0.0100
# Epoch 10/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0714
# Epoch 10: loss improved from 0.08391 to 0.07136, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0714 - lr: 0.0100
# Epoch 11/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0617
# Epoch 11: loss improved from 0.07136 to 0.06171, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0617 - lr: 0.0100
# Epoch 12/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0549
# Epoch 12: loss improved from 0.06171 to 0.05486, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0549 - lr: 0.0100
# Epoch 13/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0501
# Epoch 13: loss improved from 0.05486 to 0.05008, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0501 - lr: 0.0100
# Epoch 14/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0468
# Epoch 14: loss improved from 0.05008 to 0.04682, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 134ms/step - loss: 0.0468 - lr: 0.0100
# Epoch 15/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0445
# Epoch 15: loss improved from 0.04682 to 0.04452, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 183ms/step - loss: 0.0445 - lr: 0.0100
# Epoch 16/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0429
# Epoch 16: loss improved from 0.04452 to 0.04294, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0429 - lr: 0.0100
# Epoch 17/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0417
# Epoch 17: loss improved from 0.04294 to 0.04167, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0417 - lr: 0.0100
# Epoch 18/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0401
# Epoch 18: loss improved from 0.04167 to 0.04015, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0401 - lr: 0.0100
# Epoch 19/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0382
# Epoch 19: loss improved from 0.04015 to 0.03817, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0382 - lr: 0.0100
# Epoch 20/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0360
# Epoch 20: loss improved from 0.03817 to 0.03603, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0360 - lr: 0.0100
# Epoch 21/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0338
# Epoch 21: loss improved from 0.03603 to 0.03384, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0338 - lr: 0.0100
# Epoch 22/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0318
# Epoch 22: loss improved from 0.03384 to 0.03180, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0318 - lr: 0.0100
# Epoch 23/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0301
# Epoch 23: loss improved from 0.03180 to 0.03011, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0301 - lr: 0.0100
# Epoch 24/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0286
# Epoch 24: loss improved from 0.03011 to 0.02858, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0286 - lr: 0.0100
# Epoch 25/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0270
# Epoch 25: loss improved from 0.02858 to 0.02699, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0270 - lr: 0.0100
# Epoch 26/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0250
# Epoch 26: loss improved from 0.02699 to 0.02504, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0250 - lr: 0.0100
# Epoch 27/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0233
# Epoch 27: loss improved from 0.02504 to 0.02333, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 181ms/step - loss: 0.0233 - lr: 0.0100
# Epoch 28/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0223
# Epoch 28: loss improved from 0.02333 to 0.02226, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0223 - lr: 0.0100
# Epoch 29/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0215
# Epoch 29: loss improved from 0.02226 to 0.02150, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 97ms/step - loss: 0.0215 - lr: 0.0100
# Epoch 30/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0207
# Epoch 30: loss improved from 0.02150 to 0.02068, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0207 - lr: 0.0100
# Epoch 31/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0199
# Epoch 31: loss improved from 0.02068 to 0.01988, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0199 - lr: 0.0100
# Epoch 32/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0190
# Epoch 32: loss improved from 0.01988 to 0.01897, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 97ms/step - loss: 0.0190 - lr: 0.0100
# Epoch 33/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0180
# Epoch 33: loss improved from 0.01897 to 0.01797, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0180 - lr: 0.0100
# Epoch 34/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0169
# Epoch 34: loss improved from 0.01797 to 0.01687, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 96ms/step - loss: 0.0169 - lr: 0.0100
# Epoch 35/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0158
# Epoch 35: loss improved from 0.01687 to 0.01575, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 97ms/step - loss: 0.0158 - lr: 0.0100
# Epoch 36/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0148
# Epoch 36: loss improved from 0.01575 to 0.01480, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 97ms/step - loss: 0.0148 - lr: 0.0100
# Epoch 37/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0139
# Epoch 37: loss improved from 0.01480 to 0.01393, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 97ms/step - loss: 0.0139 - lr: 0.0100
# Epoch 38/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0131
# Epoch 38: loss improved from 0.01393 to 0.01310, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0131 - lr: 0.0100
# Epoch 39/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0123
# Epoch 39: loss improved from 0.01310 to 0.01234, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 194ms/step - loss: 0.0123 - lr: 0.0100
# Epoch 40/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0118
# Epoch 40: loss improved from 0.01234 to 0.01178, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0118 - lr: 0.0100
# Epoch 41/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0114
# Epoch 41: loss improved from 0.01178 to 0.01136, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0114 - lr: 0.0100
# Epoch 42/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0110
# Epoch 42: loss improved from 0.01136 to 0.01100, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0110 - lr: 0.0100
# Epoch 43/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 43: loss improved from 0.01100 to 0.01080, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0108 - lr: 0.0100
# Epoch 44/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 44: loss improved from 0.01080 to 0.01075, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0108 - lr: 0.0100
# Epoch 45/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 45: loss did not improve from 0.01075
# 2/2 [==============================] - 0s 90ms/step - loss: 0.0108 - lr: 0.0100
# Epoch 46/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0107
# Epoch 46: loss improved from 0.01075 to 0.01067, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0107 - lr: 0.0100
# Epoch 47/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0101
# Epoch 47: loss improved from 0.01067 to 0.01014, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0101 - lr: 0.0100
# Epoch 48/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0094
# Epoch 48: loss improved from 0.01014 to 0.00941, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0094 - lr: 0.0100
# Epoch 49/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0087
# Epoch 49: loss improved from 0.00941 to 0.00870, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 95ms/step - loss: 0.0087 - lr: 0.0100
# Epoch 50/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0081
# Epoch 50: loss improved from 0.00870 to 0.00814, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 96ms/step - loss: 0.0081 - lr: 0.0100
# Epoch 51/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 51: loss improved from 0.00814 to 0.00771, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0077 - lr: 0.0100
# Epoch 52/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 52: loss improved from 0.00771 to 0.00727, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 97ms/step - loss: 0.0073 - lr: 0.0100
# Epoch 53/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0069
# Epoch 53: loss improved from 0.00727 to 0.00691, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 92ms/step - loss: 0.0069 - lr: 0.0100
# Epoch 54/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 54: loss improved from 0.00691 to 0.00663, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 92ms/step - loss: 0.0066 - lr: 0.0100
# Epoch 55/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 55: loss improved from 0.00663 to 0.00628, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 95ms/step - loss: 0.0063 - lr: 0.0100
# Epoch 56/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 56: loss improved from 0.00628 to 0.00596, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0060 - lr: 0.0100
# Epoch 57/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 57: loss improved from 0.00596 to 0.00570, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0057 - lr: 0.0100
# Epoch 58/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 58: loss improved from 0.00570 to 0.00544, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0054 - lr: 0.0100
# Epoch 59/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 59: loss improved from 0.00544 to 0.00520, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 96ms/step - loss: 0.0052 - lr: 0.0100
# Epoch 60/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 60: loss improved from 0.00520 to 0.00494, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 95ms/step - loss: 0.0049 - lr: 0.0100
# Epoch 61/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 61: loss improved from 0.00494 to 0.00473, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0047 - lr: 0.0100
# Epoch 62/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 62: loss improved from 0.00473 to 0.00459, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0046 - lr: 0.0100
# Epoch 63/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 63: loss improved from 0.00459 to 0.00437, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0044 - lr: 0.0100
# Epoch 64/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 64: loss improved from 0.00437 to 0.00417, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0042 - lr: 0.0100
# Epoch 65/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 65: loss improved from 0.00417 to 0.00402, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0040 - lr: 0.0100
# Epoch 66/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 66: loss improved from 0.00402 to 0.00386, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 124ms/step - loss: 0.0039 - lr: 0.0100
# Epoch 67/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 67: loss improved from 0.00386 to 0.00362, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 131ms/step - loss: 0.0036 - lr: 0.0100
# Epoch 68/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 68: loss improved from 0.00362 to 0.00338, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0034 - lr: 0.0100
# Epoch 69/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 69: loss improved from 0.00338 to 0.00320, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 97ms/step - loss: 0.0032 - lr: 0.0100
# Epoch 70/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 70: loss improved from 0.00320 to 0.00312, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0031 - lr: 0.0100
# Epoch 71/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 71: loss improved from 0.00312 to 0.00305, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0030 - lr: 0.0100
# Epoch 72/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 72: loss improved from 0.00305 to 0.00294, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 96ms/step - loss: 0.0029 - lr: 0.0100
# Epoch 73/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 73: loss improved from 0.00294 to 0.00281, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 96ms/step - loss: 0.0028 - lr: 0.0100
# Epoch 74/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 74: loss improved from 0.00281 to 0.00269, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 96ms/step - loss: 0.0027 - lr: 0.0100
# Epoch 75/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 75: loss improved from 0.00269 to 0.00259, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0026 - lr: 0.0100
# Epoch 76/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 76: loss improved from 0.00259 to 0.00251, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 95ms/step - loss: 0.0025 - lr: 0.0100
# Epoch 77/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 77: loss improved from 0.00251 to 0.00244, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0024 - lr: 0.0100
# Epoch 78/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 78: loss improved from 0.00244 to 0.00237, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 95ms/step - loss: 0.0024 - lr: 0.0100
# Epoch 79/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 79: loss improved from 0.00237 to 0.00230, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 96ms/step - loss: 0.0023 - lr: 0.0100
# Epoch 80/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 80: loss improved from 0.00230 to 0.00226, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0023 - lr: 0.0100
# Epoch 81/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 81: loss improved from 0.00226 to 0.00225, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 96ms/step - loss: 0.0023 - lr: 0.0100
# Epoch 82/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 82: loss improved from 0.00225 to 0.00225, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0023 - lr: 0.0100
# Epoch 83/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 83: loss did not improve from 0.00225
# 2/2 [==============================] - 0s 91ms/step - loss: 0.0023 - lr: 0.0100
# Epoch 84/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 84: loss improved from 0.00225 to 0.00223, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0022 - lr: 0.0100
# Epoch 85/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 85: loss improved from 0.00223 to 0.00212, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0021 - lr: 0.0100
# Epoch 86/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 86: loss improved from 0.00212 to 0.00198, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 95ms/step - loss: 0.0020 - lr: 0.0100
# Epoch 87/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 87: loss improved from 0.00198 to 0.00185, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 96ms/step - loss: 0.0018 - lr: 0.0100
# Epoch 88/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 88: loss improved from 0.00185 to 0.00173, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 95ms/step - loss: 0.0017 - lr: 0.0100
# Epoch 89/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 89: loss improved from 0.00173 to 0.00171, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0017 - lr: 0.0100
# Epoch 90/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 90: loss did not improve from 0.00171
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0017 - lr: 0.0100
# Epoch 91/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 91: loss improved from 0.00171 to 0.00167, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 96ms/step - loss: 0.0017 - lr: 0.0100
# Epoch 92/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 92: loss improved from 0.00167 to 0.00163, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0016 - lr: 0.0100
# Epoch 93/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 93: loss did not improve from 0.00163
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0016 - lr: 0.0100
# Epoch 94/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 94: loss did not improve from 0.00163
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0016 - lr: 0.0100
# Epoch 95/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 95: loss improved from 0.00163 to 0.00155, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 90ms/step - loss: 0.0016 - lr: 0.0100
# Epoch 96/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 96: loss improved from 0.00155 to 0.00147, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 93ms/step - loss: 0.0015 - lr: 0.0100
# Epoch 97/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 97: loss improved from 0.00147 to 0.00144, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0014 - lr: 0.0100
# Epoch 98/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 98: loss improved from 0.00144 to 0.00140, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0014 - lr: 0.0100
# Epoch 99/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 99: loss did not improve from 0.00140
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0014 - lr: 0.0100
# Epoch 100/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 100: loss improved from 0.00140 to 0.00137, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0014 - lr: 0.0100
# Epoch 101/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 101: loss improved from 0.00137 to 0.00131, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0013 - lr: 0.0100
# Epoch 102/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 102: loss improved from 0.00131 to 0.00129, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0013 - lr: 0.0100
# Epoch 103/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 103: loss improved from 0.00129 to 0.00129, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 95ms/step - loss: 0.0013 - lr: 0.0100
# Epoch 104/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 104: loss improved from 0.00129 to 0.00127, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0013 - lr: 0.0100
# Epoch 105/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 105: loss improved from 0.00127 to 0.00122, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 97ms/step - loss: 0.0012 - lr: 0.0100
# Epoch 106/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 106: loss improved from 0.00122 to 0.00118, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0012 - lr: 0.0100
# Epoch 107/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 107: loss improved from 0.00118 to 0.00117, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 93ms/step - loss: 0.0012 - lr: 0.0100
# Epoch 108/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 108: loss did not improve from 0.00117
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0012 - lr: 0.0100
# Epoch 109/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 109: loss improved from 0.00117 to 0.00114, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 93ms/step - loss: 0.0011 - lr: 0.0100
# Epoch 110/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 110: loss did not improve from 0.00114
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0015 - lr: 0.0100
# Epoch 111/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 111: loss did not improve from 0.00114
# 2/2 [==============================] - 0s 85ms/step - loss: 0.0018 - lr: 0.0100
# Epoch 112/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 112: loss did not improve from 0.00114
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0013 - lr: 0.0100
# Epoch 113/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 113: loss improved from 0.00114 to 0.00102, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 93ms/step - loss: 0.0010 - lr: 0.0100
# Epoch 114/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 114: loss did not improve from 0.00102
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0011 - lr: 0.0100
# Epoch 115/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 115: loss did not improve from 0.00102
# 2/2 [==============================] - 0s 139ms/step - loss: 0.0011 - lr: 0.0100
# Epoch 116/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 116: loss did not improve from 0.00102
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0011 - lr: 0.0100
# Epoch 117/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 117: loss did not improve from 0.00102
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0010 - lr: 0.0100
# Epoch 118/1000
# 2/2 [==============================] - ETA: 0s - loss: 9.7083e-04
# Epoch 118: loss improved from 0.00102 to 0.00097, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 91ms/step - loss: 9.7083e-04 - lr: 0.0100
# Epoch 119/1000
# 2/2 [==============================] - ETA: 0s - loss: 9.7485e-04
# Epoch 119: loss did not improve from 0.00097
# 2/2 [==============================] - 0s 91ms/step - loss: 9.7485e-04 - lr: 0.0100
# Epoch 120/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 120: loss did not improve from 0.00097
# 2/2 [==============================] - 0s 88ms/step - loss: 0.0013 - lr: 0.0100
# Epoch 121/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 121: loss did not improve from 0.00097
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0015 - lr: 0.0100
# Epoch 122/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 122: loss did not improve from 0.00097
# 2/2 [==============================] - 0s 87ms/step - loss: 0.0014 - lr: 0.0100
# Epoch 123/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 123: loss did not improve from 0.00097
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0014 - lr: 0.0100
# Epoch 124/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 124: loss did not improve from 0.00097
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0012 - lr: 0.0100
# Epoch 125/1000
# 2/2 [==============================] - ETA: 0s - loss: 9.3529e-04
# Epoch 125: loss improved from 0.00097 to 0.00094, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 97ms/step - loss: 9.3529e-04 - lr: 0.0100
# Epoch 126/1000
# 2/2 [==============================] - ETA: 0s - loss: 9.3321e-04
# Epoch 126: loss improved from 0.00094 to 0.00093, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 101ms/step - loss: 9.3321e-04 - lr: 0.0100
# Epoch 127/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 127: loss did not improve from 0.00093
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0011 - lr: 0.0100
# Epoch 128/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 128: loss did not improve from 0.00093
# 2/2 [==============================] - 0s 92ms/step - loss: 0.0012 - lr: 0.0100
# Epoch 129/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 129: loss did not improve from 0.00093
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0012 - lr: 0.0100
# Epoch 130/1000
# 2/2 [==============================] - ETA: 0s - loss: 9.8855e-04
# Epoch 130: loss did not improve from 0.00093
# 2/2 [==============================] - 0s 83ms/step - loss: 9.8855e-04 - lr: 0.0100
# Epoch 131/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 131: loss did not improve from 0.00093
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0010 - lr: 0.0100
# Epoch 132/1000
# 2/2 [==============================] - ETA: 0s - loss: 9.6215e-04
# Epoch 132: loss did not improve from 0.00093
# 2/2 [==============================] - 0s 82ms/step - loss: 9.6215e-04 - lr: 0.0100
# Epoch 133/1000
# 2/2 [==============================] - ETA: 0s - loss: 9.2959e-04
# Epoch 133: loss improved from 0.00093 to 0.00093, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 93ms/step - loss: 9.2959e-04 - lr: 0.0100
# Epoch 134/1000
# 2/2 [==============================] - ETA: 0s - loss: 9.2548e-04
# Epoch 134: loss improved from 0.00093 to 0.00093, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 95ms/step - loss: 9.2548e-04 - lr: 0.0100
# Epoch 135/1000
# 2/2 [==============================] - ETA: 0s - loss: 8.7160e-04
# Epoch 135: loss improved from 0.00093 to 0.00087, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 95ms/step - loss: 8.7160e-04 - lr: 0.0100
# Epoch 136/1000
# 2/2 [==============================] - ETA: 0s - loss: 8.0834e-04
# Epoch 136: loss improved from 0.00087 to 0.00081, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 96ms/step - loss: 8.0834e-04 - lr: 0.0100
# Epoch 137/1000
# 2/2 [==============================] - ETA: 0s - loss: 7.5063e-04
# Epoch 137: loss improved from 0.00081 to 0.00075, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 95ms/step - loss: 7.5063e-04 - lr: 0.0100
# Epoch 138/1000
# 2/2 [==============================] - ETA: 0s - loss: 7.1649e-04
# Epoch 138: loss improved from 0.00075 to 0.00072, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 99ms/step - loss: 7.1649e-04 - lr: 0.0100
# Epoch 139/1000
# 2/2 [==============================] - ETA: 0s - loss: 7.1071e-04
# Epoch 139: loss improved from 0.00072 to 0.00071, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 106ms/step - loss: 7.1071e-04 - lr: 0.0100
# Epoch 140/1000
# 2/2 [==============================] - ETA: 0s - loss: 7.3507e-04
# Epoch 140: loss did not improve from 0.00071
# 2/2 [==============================] - 0s 84ms/step - loss: 7.3507e-04 - lr: 0.0100
# Epoch 141/1000
# 2/2 [==============================] - ETA: 0s - loss: 7.4766e-04
# Epoch 141: loss did not improve from 0.00071
# 2/2 [==============================] - 0s 85ms/step - loss: 7.4766e-04 - lr: 0.0100
# Epoch 142/1000
# 2/2 [==============================] - ETA: 0s - loss: 7.5476e-04
# Epoch 142: loss did not improve from 0.00071
# 2/2 [==============================] - 0s 92ms/step - loss: 7.5476e-04 - lr: 0.0100
# Epoch 143/1000
# 2/2 [==============================] - ETA: 0s - loss: 7.0598e-04
# Epoch 143: loss improved from 0.00071 to 0.00071, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 97ms/step - loss: 7.0598e-04 - lr: 0.0100
# Epoch 144/1000
# 2/2 [==============================] - ETA: 0s - loss: 6.8237e-04
# Epoch 144: loss improved from 0.00071 to 0.00068, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 154ms/step - loss: 6.8237e-04 - lr: 0.0100
# Epoch 145/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 145: loss did not improve from 0.00068
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0011 - lr: 0.0100
# Epoch 146/1000
# 2/2 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 146: loss did not improve from 0.00068
# ...
# 2/2 [==============================] - 0s 99ms/step - loss: 4.4826e-04 - lr: 1.0000e-04
# Epoch 276/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4821e-04
# Epoch 276: loss improved from 0.00045 to 0.00045, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 95ms/step - loss: 4.4821e-04 - lr: 1.0000e-04
# Epoch 277/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4815e-04
# Epoch 277: loss improved from 0.00045 to 0.00045, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 92ms/step - loss: 4.4815e-04 - lr: 1.0000e-04
# Epoch 278/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4803e-04
# Epoch 278: loss improved from 0.00045 to 0.00045, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 95ms/step - loss: 4.4803e-04 - lr: 1.0000e-04
# Epoch 279/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4800e-04
# Epoch 279: loss improved from 0.00045 to 0.00045, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 98ms/step - loss: 4.4800e-04 - lr: 1.0000e-04
# Epoch 280/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4813e-04
# Epoch 280: loss did not improve from 0.00045
# 2/2 [==============================] - 0s 88ms/step - loss: 4.4813e-04 - lr: 1.0000e-04
# Epoch 281/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4803e-04
# Epoch 281: loss did not improve from 0.00045
# 2/2 [==============================] - 0s 86ms/step - loss: 4.4803e-04 - lr: 1.0000e-04
# Epoch 282/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4762e-04
# Epoch 282: loss improved from 0.00045 to 0.00045, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 4.4762e-04 - lr: 1.0000e-04
# Epoch 283/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4722e-04
# Epoch 283: loss improved from 0.00045 to 0.00045, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 103ms/step - loss: 4.4722e-04 - lr: 1.0000e-04
# Epoch 284/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4688e-04
# Epoch 284: loss improved from 0.00045 to 0.00045, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 98ms/step - loss: 4.4688e-04 - lr: 1.0000e-04
# Epoch 285/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4665e-04
# Epoch 285: loss improved from 0.00045 to 0.00045, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 91ms/step - loss: 4.4665e-04 - lr: 1.0000e-04
# Epoch 286/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4648e-04
# Epoch 286: loss improved from 0.00045 to 0.00045, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 94ms/step - loss: 4.4648e-04 - lr: 1.0000e-04
# Epoch 287/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4631e-04
# Epoch 287: loss improved from 0.00045 to 0.00045, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 98ms/step - loss: 4.4631e-04 - lr: 1.0000e-04
# Epoch 288/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4603e-04
# Epoch 288: loss improved from 0.00045 to 0.00045, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 98ms/step - loss: 4.4603e-04 - lr: 1.0000e-04
# Epoch 289/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4571e-04
# Epoch 289: loss improved from 0.00045 to 0.00045, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 94ms/step - loss: 4.4571e-04 - lr: 1.0000e-04
# Epoch 290/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4538e-04
# Epoch 290: loss improved from 0.00045 to 0.00045, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 98ms/step - loss: 4.4538e-04 - lr: 1.0000e-04
# Epoch 291/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4511e-04
# Epoch 291: loss improved from 0.00045 to 0.00045, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 95ms/step - loss: 4.4511e-04 - lr: 1.0000e-04
# Epoch 292/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4499e-04
# Epoch 292: loss improved from 0.00045 to 0.00044, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 101ms/step - loss: 4.4499e-04 - lr: 1.0000e-04
# Epoch 293/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4489e-04
# Epoch 293: loss improved from 0.00044 to 0.00044, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 4.4489e-04 - lr: 1.0000e-04
# Epoch 294/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4482e-04
# Epoch 294: loss improved from 0.00044 to 0.00044, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 93ms/step - loss: 4.4482e-04 - lr: 1.0000e-04
# Epoch 295/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4476e-04
# Epoch 295: loss improved from 0.00044 to 0.00044, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 93ms/step - loss: 4.4476e-04 - lr: 1.0000e-04
# Epoch 296/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4466e-04
# Epoch 296: loss improved from 0.00044 to 0.00044, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 93ms/step - loss: 4.4466e-04 - lr: 1.0000e-04
# Epoch 297/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4456e-04
# Epoch 297: loss improved from 0.00044 to 0.00044, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 92ms/step - loss: 4.4456e-04 - lr: 1.0000e-04
# Epoch 298/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4449e-04
# Epoch 298: loss improved from 0.00044 to 0.00044, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 98ms/step - loss: 4.4449e-04 - lr: 1.0000e-04
# Epoch 299/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4430e-04
# Epoch 299: loss improved from 0.00044 to 0.00044, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 102ms/step - loss: 4.4430e-04 - lr: 1.0000e-04
# Epoch 300/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4407e-04
# Epoch 300: loss improved from 0.00044 to 0.00044, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 111ms/step - loss: 4.4407e-04 - lr: 1.0000e-04
# Epoch 301/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4396e-04
# Epoch 301: loss improved from 0.00044 to 0.00044, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 94ms/step - loss: 4.4396e-04 - lr: 1.0000e-04
# Epoch 302/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4375e-04
# Epoch 302: loss improved from 0.00044 to 0.00044, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 109ms/step - loss: 4.4375e-04 - lr: 1.0000e-04
# Epoch 303/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4346e-04
# Epoch 303: loss improved from 0.00044 to 0.00044, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 96ms/step - loss: 4.4346e-04 - lr: 1.0000e-04
# Epoch 304/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4323e-04
# Epoch 304: loss improved from 0.00044 to 0.00044, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 108ms/step - loss: 4.4323e-04 - lr: 1.0000e-04
# Epoch 305/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4307e-04
# Epoch 305: loss improved from 0.00044 to 0.00044, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 105ms/step - loss: 4.4307e-04 - lr: 1.0000e-04
# Epoch 306/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4285e-04
# Epoch 306: loss improved from 0.00044 to 0.00044, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 98ms/step - loss: 4.4285e-04 - lr: 1.0000e-04
# Epoch 307/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4266e-04
# Epoch 307: loss improved from 0.00044 to 0.00044, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 104ms/step - loss: 4.4266e-04 - lr: 1.0000e-04
# Epoch 308/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4253e-04
# Epoch 308: loss improved from 0.00044 to 0.00044, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 119ms/step - loss: 4.4253e-04 - lr: 1.0000e-04
# Epoch 309/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4243e-04
# Epoch 309: loss improved from 0.00044 to 0.00044, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 112ms/step - loss: 4.4243e-04 - lr: 1.0000e-04
# Epoch 310/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4232e-04
# Epoch 310: loss improved from 0.00044 to 0.00044, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 103ms/step - loss: 4.4232e-04 - lr: 1.0000e-04
# Epoch 311/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4224e-04
# Epoch 311: loss improved from 0.00044 to 0.00044, saving model to ./models/Lattice/weight/wine3_1000query_2column_1000epoch.h5
# 2/2 [==============================] - 0s 101ms/step - loss: 4.4224e-04 - lr: 1.0000e-04
# Epoch 312/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4237e-04
# Epoch 312: loss did not improve from 0.00044
# 2/2 [==============================] - 0s 96ms/step - loss: 4.4237e-04 - lr: 1.0000e-04
# Epoch 313/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4266e-04
# Epoch 313: loss did not improve from 0.00044
# 2/2 [==============================] - 0s 90ms/step - loss: 4.4266e-04 - lr: 1.0000e-04
# Epoch 314/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4291e-04
# Epoch 314: loss did not improve from 0.00044
# 2/2 [==============================] - 0s 91ms/step - loss: 4.4291e-04 - lr: 1.0000e-04
# Epoch 315/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4311e-04
# Epoch 315: loss did not improve from 0.00044
# 2/2 [==============================] - 0s 83ms/step - loss: 4.4311e-04 - lr: 1.0000e-04
# Epoch 316/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4325e-04
# Epoch 316: loss did not improve from 0.00044
# 2/2 [==============================] - 0s 95ms/step - loss: 4.4325e-04 - lr: 1.0000e-04
# Epoch 317/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4338e-04
# Epoch 317: loss did not improve from 0.00044
# 2/2 [==============================] - 0s 99ms/step - loss: 4.4338e-04 - lr: 1.0000e-04
# Epoch 318/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4357e-04
# Epoch 318: loss did not improve from 0.00044
# 2/2 [==============================] - 0s 84ms/step - loss: 4.4357e-04 - lr: 1.0000e-04
# Epoch 319/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4386e-04
# Epoch 319: loss did not improve from 0.00044
# 2/2 [==============================] - 0s 87ms/step - loss: 4.4386e-04 - lr: 1.0000e-04
# Epoch 320/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4416e-04
# Epoch 320: loss did not improve from 0.00044
# 2/2 [==============================] - 0s 94ms/step - loss: 4.4416e-04 - lr: 1.0000e-04
# Epoch 321/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4450e-04
# Epoch 321: loss did not improve from 0.00044
#
# Epoch 321: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
# 2/2 [==============================] - 0s 94ms/step - loss: 4.4450e-04 - lr: 1.0000e-04
# Epoch 322/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4494e-04
# Epoch 322: loss did not improve from 0.00044
# 2/2 [==============================] - 0s 100ms/step - loss: 4.4494e-04 - lr: 1.0000e-05
# Epoch 323/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4500e-04
# Epoch 323: loss did not improve from 0.00044
# 2/2 [==============================] - 0s 90ms/step - loss: 4.4500e-04 - lr: 1.0000e-05
# Epoch 324/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4505e-04
# Epoch 324: loss did not improve from 0.00044
# 2/2 [==============================] - 0s 95ms/step - loss: 4.4505e-04 - lr: 1.0000e-05
# Epoch 325/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4509e-04
# Epoch 325: loss did not improve from 0.00044
# 2/2 [==============================] - 0s 104ms/step - loss: 4.4509e-04 - lr: 1.0000e-05
# Epoch 326/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4513e-04
# Epoch 326: loss did not improve from 0.00044
# 2/2 [==============================] - 0s 82ms/step - loss: 4.4513e-04 - lr: 1.0000e-05
# Epoch 327/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4517e-04
# Epoch 327: loss did not improve from 0.00044
# 2/2 [==============================] - 0s 81ms/step - loss: 4.4517e-04 - lr: 1.0000e-05
# Epoch 328/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4520e-04
# Epoch 328: loss did not improve from 0.00044
# 2/2 [==============================] - 0s 92ms/step - loss: 4.4520e-04 - lr: 1.0000e-05
# Epoch 329/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4519e-04
# Epoch 329: loss did not improve from 0.00044
# 2/2 [==============================] - 0s 88ms/step - loss: 4.4519e-04 - lr: 1.0000e-05
# Epoch 330/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4514e-04
# Epoch 330: loss did not improve from 0.00044
# 2/2 [==============================] - 0s 160ms/step - loss: 4.4514e-04 - lr: 1.0000e-05
# Epoch 331/1000
# 2/2 [==============================] - ETA: 0s - loss: 4.4506e-04Restoring model weights from the end of the best epoch: 311.
#
# Epoch 331: loss did not improve from 0.00044
#
# Epoch 331: ReduceLROnPlateau reducing learning rate to 9.99999883788405e-07.
# 2/2 [==============================] - 0s 110ms/step - loss: 4.4506e-04 - lr: 1.0000e-05
# Epoch 331: early stopping
#
# Finish training
# Begin model inference
# 313/313 [==============================] - 3s 7ms/step
# Done
#
# Begin generating table...
#   1%|          | 74/9846 [00:00<00:13, 733.76it/s]
# 4
#  46%|████▌     | 4536/9846 [00:06<00:07, 699.91it/s]
# Reached table length in  4536 9846
#
# Finish generate table, calculating Q-error on new table...
# 100%|██████████| 1000/1000 [00:01<00:00, 936.41it/s]
#  Q-error of Lattice (query size=1000, condition=2, epoches=1000):
#
# min:    1.000825763831544
# 10:     1.0389637056230645
# 20:     1.0758235252221293
# 30:     1.1291895550865116
# 40:     1.1760886914134117
# median: 1.2727369652365692
# 60:     1.485608856088561
# 70:     1.9170927497992425
# 80:     2.9153356104966393
# 90:     6.6433354445585024
# 95:     10.12547268907563
# max:    185.0
# mean:   3.210055265631746
#
# original table shape: (6497, 3)
#   Our table shape   : (6497, 3)

# %%
lhs_n = 10000
lb = np.array([1] * n_column)
ub = np.array(column_interval_number) - 1
lhs_sample = lb + (ub - lb) * lhs(n_column, samples=lhs_n, criterion="center")
index = np.round(lhs_sample).astype(np.int)
grid_mesh = np.empty_like(index, dtype=np.float)
for i in range(lhs_n):
    idx = index[i, :]
    grid_mesh[i] = [unique_intervals[j][idx[j]] for j in range(n_column)]
sample_df = pd.DataFrame(grid_mesh, columns=[f"col_{i}" for i in range(n_column)])
grid = np.array(sample_df.sort_values(by=list(sample_df.columns)))

# %%
lb = np.array([v[1] for v in unique_intervals.values()])
ub = np.array([v[-1] for v in unique_intervals.values()])
lhs_sample = lhs(n_column, samples=10000, criterion="center")
sample_df = pd.DataFrame(lb + (ub - lb) * lhs_sample, columns=[f"col_{i}" for i in range(n_column)])
grid = np.array(sample_df.sort_values(by=list(sample_df.columns)))
grid

# %%
data = lhs(3, samples=100, criterion="center")
fig3 = plt.figure(figsize=(10, 10))
ax3 = plt.axes(projection="3d")
x = data[:, 0]
y = data[:, 1]
z = data[:, 2]
ax3.scatter3D(x, y, z, cmap="b")
plt.show()

# %%
data = lhs(2, samples=10000, criterion="center")
plt.figure(figsize=(10, 10))
plt.plot(data[:, 0], data[:, 1], "o")

# %%
from scipy.stats import qmc

sampler = qmc.LatinHypercube(d=2)
sample = sampler.random(n=5)
sample

# %%
# 对 train 做一个数据增强，边界点必须要加入，起码加进去两个0点和1个最大点

# %%
[v[-1] for v in unique_intervals.values()]

# %%
m.inference(np.array([[0, 14.4, 0, 2.33, 0, 1.76]])) * n_row
