# %%
import sys
import time
import common
import argparse
import datasets
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm, trange
from matplotlib import pyplot as plt
import estimators as estimators_lib
import tensorflow as tf
import tensorflow_lattice as tfl
plt.style.use('ggplot')
# %matplotlib inline
# %config InlineBackend.figure_format='retina'


def Oracle(table, query):
    cols, idxs, ops, vals = query
    oracle_est = estimators_lib.Oracle(table)
    return oracle_est.Query(cols, ops, vals)


def cal_true_card(query, table):
    cols, idxs, ops, vals = query
    ops = np.array(ops)
    probs = Oracle(table, (cols, idxs, ops, vals))
    return probs


def GenerateQuery(table, min_num_filters, max_num_filters, rng, dataset):
    """Generate a random query."""
    num_filters = rng.randint(max_num_filters - 1, max_num_filters)
    cols, idxs, ops, vals = SampleTupleThenRandom(table, num_filters, rng,
                                                  dataset)
    sel = cal_true_card(
        (cols, idxs, ops, vals), table) / float(table.cardinality)
    return cols, idxs, ops, vals, sel


def SampleTupleThenRandom(table, num_filters, rng, dataset):
    vals = []
    new_table = table.data
    s = new_table.iloc[rng.randint(0, new_table.shape[0])]
    vals = s.values

    idxs = rng.choice(len(table.columns), replace=False, size=num_filters)
    cols = np.take(table.columns, idxs)
    # If dom size >= 10, okay to place a range filter.
    # Otherwise, low domain size columns should be queried with equality.
    #ops = rng.choice(['='], size=num_filters)
    ops = rng.choice(['<=', '>=', '>', '<'], size=num_filters)
    #ops = rng.choice(['<=', '>='], size=num_filters)
    #ops = rng.choice(['<='], size=num_filters)
    #ops_all_eqs = ['='] * num_filters
    #sensible_to_do_range = [c.DistributionSize() >= 10 for c in cols]
    #ops = np.where(sensible_to_do_range, ops, ops_all_eqs)
    # if num_filters == len(table.columns):
    #     return table.columns,np.arange(len(table.columns)), ops, vals
    vals = vals[idxs]
    op_a = []
    val_a = []
    for i in range(len(vals)):
        val_a.append([vals[i]])
        op_a.append([ops[i]])
    return cols, idxs, pd.DataFrame(op_a).values, pd.DataFrame(val_a).values


def dictionary_column_interval(table_size, query_set):
    # Traverse all queries to apply the intervalization skill for each column
    n_column = table_size[1]
    column_interval = {}
    for i in range(n_column):
        column_interval[i] = set()
    for query in query_set:
        _, col_idxs, _, vals, _ = query
        for i in range(len(col_idxs)):
            column_interval[col_idxs[i]].add(vals[i][0])
    for k, v in column_interval.items():
        column_interval[k] = sorted(list(v))
        least, great = column_interval[k][0], column_interval[k][-1]
        column_interval[k] = sorted([0, least/2] + column_interval[k] + [great+1])
    return column_interval


def count_column_unique_interval(unique_intervals):
    # count unique query interval in each column
    return [len(v) for v in unique_intervals.values()]


def seperate_train_test(train_size, unique_intervals, query_set):
    X, Y = [], []
    origin = np.array([[0, v[-1]] for v in unique_intervals.values()]).ravel()
    for query in query_set:
        x = list(origin)
        _, col_idxs, ops, vals, sel = query
        for i in range(len(col_idxs)):
            if ops[i][0] == "<=":
                x[col_idxs[i]*2+1] = vals[i][0]
            elif ops[i][0] == "<":
                ind = unique_intervals[col_idxs[i]].index(vals[i][0]) - 1
                x[col_idxs[i]*2+1] = unique_intervals[col_idxs[i]][ind]
            elif ops[i][0] == ">":
                x[col_idxs[i]*2] = vals[i][0]
            elif ops[i][0] == ">=":
                ind = unique_intervals[col_idxs[i]].index(vals[i][0]) + 1
                x[col_idxs[i]*2] = unique_intervals[col_idxs[i]][ind]
            elif ops[i][0] == "=":
                ind = unique_intervals[col_idxs[i]].index(vals[i][0]) - 1
                x[col_idxs[i]*2] = unique_intervals[col_idxs[i]][ind]
                x[col_idxs[i]*2+1] = vals[i][0]
        X.append(x)
        Y.append(sel)
    X = np.array(X).astype(np.float32)
    Y = np.array(Y).astype(np.float32).reshape(-1, 1)
    total = np.concatenate((X, Y), axis=1)
    #total = np.unique(total, axis=0)
    choose = np.random.choice(total.shape[0], size=round(total.shape[0]*train_size), replace=False)
    others = list(set(range(total.shape[0])) - set(choose))
    train, test = total[choose], total[others]

    df_train = pd.DataFrame(train, columns=[f'col_{i}' for i in range(total.shape[1])])
    new_train = np.array(df_train.sort_values(by=list(df_train.columns)[:-1]))
    train_X, train_Y = np.hsplit(new_train, [-1])

    df_test = pd.DataFrame(test, columns=[f'col_{i}' for i in range(total.shape[1])])
    new_test = np.array(df_test.sort_values(by=list(df_test.columns)[:-1]))
    test_X, test_Y = np.hsplit(new_test, [-1])
    return train_X, train_Y, test_X, test_Y


class LatticeCDF:
    def __init__(
            self,
            name,
            n_row,
            unique_intervals,
            pwl_keypoints=None,  # also can input table unique values
            lattice_size=2):

        self.model_path = './models/Lattice/model/' + name
        self.weight_path = './models/Lattice/weight/' + name
        self.n_row = n_row
        self.dim = len(unique_intervals.keys())
        self.lattice_size = lattice_size
        self.unique_intervals = unique_intervals
        self.pwl_calibration_input_keypoints = unique_intervals if pwl_keypoints is None else pwl_keypoints

        self.model_inputs = []
        for i in range(self.dim):
#             self.model_inputs.append(
#                 tf.keras.layers.Input(shape=[1], name='col_%s' % i))
            self.model_inputs.append(
                tf.keras.layers.Input(shape=[1], name='col%s_l' % i))
            self.model_inputs.append(
                tf.keras.layers.Input(shape=[1], name='col%s_u' % i))

        self.calibrators = []
        for i in range(self.dim):
            self.calibrators.append(
                tfl.layers.PWLCalibration(
                    input_keypoints=np.array(
                        self.pwl_calibration_input_keypoints[i]),
                    dtype=tf.float32,
                    output_min=0.0,
                    output_max=1.0,
                    monotonicity='decreasing',
                ))
            self.calibrators.append(
                tfl.layers.PWLCalibration(
                    input_keypoints=np.array(
                        self.pwl_calibration_input_keypoints[i]),
                    # input_keypoints=np.linspace(
                    #     feat_mins[i],
                    #     feat_maxs[i],
                    #     num=pwl_calibration_num_keypoints),
                    dtype=tf.float32,
                    output_min=0.0,
                    output_max=1.0,
                    monotonicity='increasing',
                ))

        self.lattice_inputs = []
        for i in range(self.dim * 2):  # (self.dim) * 2):
            self.lattice_inputs.append(self.calibrators[i](
                self.model_inputs[i]))

        self.lattice = tfl.layers.Lattice(
            lattice_sizes=[lattice_size] * self.dim * 2,  # (self.dim * 2),
            #lattice_sizes=[len(v) for v in self.unique_intervals.values()],
            interpolation='hypercube',  # 可以尝试别的插值类型
            monotonicities=['increasing'] * self.dim * 2,  # (self.dim * 2),
            output_min= 0.0,
            output_max= 1.0,
            name='lattice',
        )
        
        self.model_output = self.lattice(self.lattice_inputs)

        self.model = tf.keras.models.Model(
            inputs=self.model_inputs,
            outputs= self.model_output
        )
        self.model.save('%s.hdf5' % self.model_path)
        self.model.summary()


    def fit(self,
            X,
            y,
            lr=0.01,
            bs=16,
            epochs=3000,
            reduceLR_factor=0.5,
            reduceLR_patience=20,
            verbose=1,
            loss='MSE',
            opt='Adam'):
        assert X.shape[0] == y.shape[0]

        X = X.astype(np.float32)
        y = y.astype(np.float32)

        features = [X[:, i] for i in range(X.shape[1])]
        target = y

        Loss = {
            'MAE': tf.keras.losses.mean_absolute_error,
            'MSE': tf.keras.losses.mean_squared_error,
            'MAPE': tf.keras.losses.mean_absolute_percentage_error
        }

        Opt = {
            'Adam': tf.keras.optimizers.Adam(),
            'Nadam': tf.keras.optimizers.Nadam(),
            'Adagrad': tf.keras.optimizers.Adagrad(),
            'Adadelta': tf.keras.optimizers.Adadelta(),
            'Adamax': tf.keras.optimizers.Adamax(),
            'RMSprop': tf.keras.optimizers.RMSprop(),
        }
        self.model.compile(loss=Loss[loss], optimizer=Opt[opt])

        earlyStopping = tf.keras.callbacks.EarlyStopping(monitor='loss',
                                                         patience=500,
                                                         verbose=verbose,
                                                         mode='min')
        mcp_save = tf.keras.callbacks.ModelCheckpoint('%s.hdf5' %
                                                      self.weight_path,
                                                      save_best_only=True,
                                                      monitor='loss',
                                                      mode='min',
                                                      save_weights_only=True)
        reduce_lr_loss = tf.keras.callbacks.ReduceLROnPlateau(
            monitor='loss',
            factor=reduceLR_factor,
            patience=reduceLR_patience,
            verbose=verbose,
            epsilon=1e-10,
            mode='min')

        self.model.fit(features,
                       target,
                       epochs=epochs,
                       batch_size=bs,
                       verbose=1,
                       callbacks=[earlyStopping, mcp_save, reduce_lr_loss])
        self.model.load_weights('%s.hdf5' % self.weight_path)

    def load(self):
        self.model = tf.keras.models.load_model('%s.hdf5' % self.model_path)
        self.model.load_weights('%s.hdf5' % self.weight_path)

    def inference(self, grid):
        assert grid.shape[1] == self.dim * 2
#         length = grid.shape[0]
#         grid_dict = {}
#         for i in range(grid.shape[1]):
#             grid_dict[f'col_{i}_l'] = [0] * length
#             grid_dict[f'col_{i}_u'] = grid[:, i]
#         extend_grid = np.array(pd.DataFrame(grid_dict))
#         pred = m.model.predict(np.hsplit(extend_grid, self.dim * 2))
        pred = m.model.predict(np.hsplit(grid, self.dim * 2))
        return pred

# %%
if __name__ == '__main__':
    parser = argparse.ArgumentParser()
    parser.add_argument('--dataset',
                        type=str,
                        default='wine1',
                        help='Dataset.')
    parser.add_argument('--loss', type=str, default='MSE', help='Loss.')
    parser.add_argument('--opt', type=str, default='Adam', help='Optimizer.')
    parser.add_argument('--query-size',
                        type=int,
                        default=3000,
                        help='query size')
    parser.add_argument('--train-size',
                        type=float,
                        default=0.8,
                        help='train size')
    parser.add_argument('--num-conditions',
                        type=int,
                        default=1,
                        help='num of conditions')
    parser.add_argument('--lr', type=float, default=1e-2, help='learning rate')
    parser.add_argument('--bs', type=int, default=1000, help='Batch size.')
    parser.add_argument('--lattice', type=int, default=2, help='Lattice size.')
    parser.add_argument('--seed', type=int, default=4321, help='Random seed')
    parser.add_argument('--sample',
                        type=int,
                        default=0,
                        help='reload trained mode')
    parser.add_argument('--epochs',
                        type=int,
                        default=10,
                        help='Number of epochs to train for.')
    #args = parser.parse_args()
    args, unknown = parser.parse_known_args()
    bs = int(args.bs)
    lr = float(args.lr)
    train_size = float(args.train_size)
    epochs = int(args.epochs)
    lattice = int(args.lattice)
    sample = int(args.sample)

    type_casts = {}
    table = datasets.LoadDataset(args.dataset + '.csv',
                                 args.dataset,
                                 type_casts=type_casts)
    print('Begin Generating Queries ...')
    time0 = time.time()
    rng = np.random.RandomState(args.seed)
    query_set = [
        GenerateQuery(table, 2, args.num_conditions + 1, rng, args.dataset)
        for i in trange(args.query_size)
    ]
    print('Complete Generating Queries.')

    # Lattice
    print("\n\nBuilding Lattice...")
    time1 = time.time()
    table_size = table.data.shape
    n_row, n_column = table_size[0], table_size[1]
    unique_intervals = dictionary_column_interval(table_size, query_set)
    column_interval_number = count_column_unique_interval(unique_intervals)
    train_X, train_Y, test_X, test_Y = seperate_train_test(train_size, unique_intervals, query_set)
    print("train set:", train_X.shape[0])
    print("test set:", test_X.shape[0])
    name = f"{args.dataset}_{args.query_size}query_{args.num_conditions}column_{args.epochs}epoch"
    m = LatticeCDF(name, n_row, unique_intervals, pwl_keypoints=None)
    
    print("\n\nLattice is already built, begin training...\n")
    time2 = time.time()
    m.fit(train_X,
          train_Y,
          lr=lr,
          bs=bs,
          epochs=2000,
          loss=args.loss,
          opt=args.opt
         )
# Out:
# load dataset wine1.csv done
# (6497, 1)
# (6497, 1)
# 0
# 0 106
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# train: 2400

# %%
values = [v for v in unique_intervals.values()] * 2
mesh = np.meshgrid(*values)  # 所有unique interval 的笛卡尔积网格
grid = np.array(mesh).T.reshape(-1, len(values)).astype(np.float32)

# %%
grid
# Out:
# (8464, 2)

# %%
m.inference(np.array([[0,0]]))
# Out:
# array([[0.02190484]], dtype=float32)

# %%
m.inference(np.array([[0,14.7]]))
# Out:
# array([[0.99558073]], dtype=float32)

# %%
m.inference(np.array([[2,14.7]]))
# Out:
# array([[0.9955763]], dtype=float32)

# %%
train_X
# Out:
# array([[ 0. ,  4.7],
#        [ 0. ,  4.7],
#        [ 0. ,  4.9],
#        ...,
#        [13.3, 16.9],
#        [13.4, 16.9],
#        [13.7, 16.9]], dtype=float32)

# %%
train_Y
# Out:
# array([[0.00246268],
#        [0.00246268],
#        [0.00507927],
#        ...,
#        [0.00230876],
#        [0.00277051],
#        [0.00230876]], dtype=float32)

# %%
pred = m.inference(grid)
#m.plotting(grid, pred)

# %%
# 增加边界点，看看对比的效果
# 增加epoch，看看误差和图形效果
# 增加query size，看看误差和效果

# %%
Xshape = len(np.unique(grid[:, 0]))
Yshape = len(np.unique(grid[:, 1]))
X = grid[:, 0].reshape(Xshape, Yshape)
Y = grid[:, 1].reshape(Xshape, Yshape)
Z = pred.reshape(Xshape, Yshape)

fig1 = plt.figure(figsize=(15, 8))
ax1 = plt.axes(projection='3d')
ax1.plot_surface(X, Y, Z, cmap='viridis')
plt.show()

fig2 = plt.figure(figsize=(10, 8))
ax2 = fig2.add_subplot(111)
cs = ax2.contourf(X, Y, Z, cmap='viridis')
# Alternatively, you can manually set the levels
# and the norm:
# lev_exp = np.arange(np.floor(np.log10(z.min())-1),
#                    np.ceil(np.log10(z.max())+1))
# levs = np.power(10, lev_exp)
# cs = ax.contourf(X, Y, z, levs, norm=colors.LogNorm())    # ??
cbar = fig2.colorbar(cs)  # 让colorbar细粒度更高一点
plt.show()

# %%
def show(epochs_list):
    fig = plt.figure(figsize=(20,8))
    for epochs in epochs_list:
        m = LatticeCDF(name, n_row, unique_intervals, pwl_keypoints=None)
        m.fit(train_X,
              train_Y,
              lr=lr,
              bs=bs,
              epochs=epochs,
              loss=args.loss,
              opt=args.opt)
        plt.plot(train_X, m.model.predict(train_X), label=f'{epochs}')
    plt.legend()
    plt.show()

# %%
show(range(1, 300, 50))
# Out:
# Model: "model_69"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# col_0 (InputLayer)           [(None, 1)]               0
# _________________________________________________________________
# lattice (Lattice)            (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Train on 38 samples
# 38/38 [==============================] - 0s 6ms/sample - loss: 0.3512
# Model: "model_70"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# col_0 (InputLayer)           [(None, 1)]               0
# _________________________________________________________________
# lattice (Lattice)            (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Train on 38 samples
# Epoch 1/51
# 38/38 [==============================] - 0s 6ms/sample - loss: 0.3512
# Epoch 2/51
# 38/38 [==============================] - 0s 127us/sample - loss: 0.3502
# Epoch 3/51
# 38/38 [==============================] - 0s 123us/sample - loss: 0.3492
# Epoch 4/51
# 38/38 [==============================] - 0s 126us/sample - loss: 0.3482
# Epoch 5/51
# 38/38 [==============================] - 0s 144us/sample - loss: 0.3473
# Epoch 6/51
# 38/38 [==============================] - 0s 132us/sample - loss: 0.3463
# Epoch 7/51
# 38/38 [==============================] - 0s 122us/sample - loss: 0.3453
# Epoch 8/51
# 38/38 [==============================] - 0s 146us/sample - loss: 0.3444
# Epoch 9/51
# 38/38 [==============================] - 0s 127us/sample - loss: 0.3434
# Epoch 10/51
# 38/38 [==============================] - 0s 123us/sample - loss: 0.3424
# Epoch 11/51
# 38/38 [==============================] - 0s 146us/sample - loss: 0.3415
# Epoch 12/51
# 38/38 [==============================] - 0s 138us/sample - loss: 0.3405
# Epoch 13/51
# 38/38 [==============================] - 0s 125us/sample - loss: 0.3396
# Epoch 14/51
# 38/38 [==============================] - 0s 128us/sample - loss: 0.3386
# Epoch 15/51
# 38/38 [==============================] - 0s 121us/sample - loss: 0.3377
# Epoch 16/51
# 38/38 [==============================] - 0s 149us/sample - loss: 0.3367
# Epoch 17/51
# 38/38 [==============================] - 0s 133us/sample - loss: 0.3358
# Epoch 18/51
# 38/38 [==============================] - 0s 127us/sample - loss: 0.3348
# Epoch 19/51
# 38/38 [==============================] - 0s 139us/sample - loss: 0.3339
# Epoch 20/51
# 38/38 [==============================] - 0s 130us/sample - loss: 0.3329
# Epoch 21/51
# 38/38 [==============================] - 0s 122us/sample - loss: 0.3320
# Epoch 22/51
# 38/38 [==============================] - 0s 149us/sample - loss: 0.3311
# Epoch 23/51
# 38/38 [==============================] - 0s 140us/sample - loss: 0.3301
# Epoch 24/51
# 38/38 [==============================] - 0s 133us/sample - loss: 0.3292
# Epoch 25/51
# 38/38 [==============================] - 0s 131us/sample - loss: 0.3283
# Epoch 26/51
# 38/38 [==============================] - 0s 125us/sample - loss: 0.3274
# Epoch 27/51
# 38/38 [==============================] - 0s 149us/sample - loss: 0.3265
# Epoch 28/51
# 38/38 [==============================] - 0s 150us/sample - loss: 0.3255
# Epoch 29/51
# 38/38 [==============================] - 0s 137us/sample - loss: 0.3246
# Epoch 30/51
# 38/38 [==============================] - 0s 122us/sample - loss: 0.3237
# Epoch 31/51
# 38/38 [==============================] - 0s 140us/sample - loss: 0.3228
# Epoch 32/51
# 38/38 [==============================] - 0s 122us/sample - loss: 0.3219
# Epoch 33/51
# 38/38 [==============================] - 0s 141us/sample - loss: 0.3210
# Epoch 34/51
# 38/38 [==============================] - 0s 149us/sample - loss: 0.3201
# Epoch 35/51
# 38/38 [==============================] - 0s 133us/sample - loss: 0.3192
# Epoch 36/51
# 38/38 [==============================] - 0s 139us/sample - loss: 0.3183
# Epoch 37/51
# 38/38 [==============================] - 0s 144us/sample - loss: 0.3174
# Epoch 38/51
# 38/38 [==============================] - 0s 144us/sample - loss: 0.3165
# Epoch 39/51
# 38/38 [==============================] - 0s 173us/sample - loss: 0.3156
# Epoch 40/51
# 38/38 [==============================] - 0s 141us/sample - loss: 0.3148
# Epoch 41/51
# 38/38 [==============================] - 0s 132us/sample - loss: 0.3139
# Epoch 42/51
# 38/38 [==============================] - 0s 148us/sample - loss: 0.3130
# Epoch 43/51
# 38/38 [==============================] - 0s 143us/sample - loss: 0.3121
# Epoch 44/51
# 38/38 [==============================] - 0s 157us/sample - loss: 0.3112
# Epoch 45/51
# 38/38 [==============================] - 0s 130us/sample - loss: 0.3104
# Epoch 46/51
# 38/38 [==============================] - 0s 128us/sample - loss: 0.3095
# Epoch 47/51
# 38/38 [==============================] - 0s 130us/sample - loss: 0.3086
# Epoch 48/51
# 38/38 [==============================] - 0s 127us/sample - loss: 0.3078
# Epoch 49/51
# 38/38 [==============================] - 0s 153us/sample - loss: 0.3069
# Epoch 50/51
# 38/38 [==============================] - 0s 159us/sample - loss: 0.3061
# Epoch 51/51
# 38/38 [==============================] - 0s 140us/sample - loss: 0.3052
# Model: "model_71"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# col_0 (InputLayer)           [(None, 1)]               0
# _________________________________________________________________
# lattice (Lattice)            (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Train on 38 samples
# Epoch 1/101
# 38/38 [==============================] - 0s 6ms/sample - loss: 0.3512
# Epoch 2/101
# 38/38 [==============================] - 0s 149us/sample - loss: 0.3502
# Epoch 3/101
# 38/38 [==============================] - 0s 117us/sample - loss: 0.3492
# Epoch 4/101
# 38/38 [==============================] - 0s 133us/sample - loss: 0.3482
# Epoch 5/101
# 38/38 [==============================] - 0s 143us/sample - loss: 0.3473
# Epoch 6/101
# 38/38 [==============================] - 0s 129us/sample - loss: 0.3463
# Epoch 7/101
# 38/38 [==============================] - 0s 117us/sample - loss: 0.3453
# Epoch 8/101
# 38/38 [==============================] - 0s 129us/sample - loss: 0.3444
# Epoch 9/101
# 38/38 [==============================] - 0s 122us/sample - loss: 0.3434
# Epoch 10/101
# 38/38 [==============================] - 0s 124us/sample - loss: 0.3424
# Epoch 11/101
# 38/38 [==============================] - 0s 143us/sample - loss: 0.3415
# Epoch 12/101
# 38/38 [==============================] - 0s 128us/sample - loss: 0.3405
# Epoch 13/101
# 38/38 [==============================] - 0s 119us/sample - loss: 0.3396
# Epoch 14/101
# 38/38 [==============================] - 0s 141us/sample - loss: 0.3386
# Epoch 15/101
# 38/38 [==============================] - 0s 134us/sample - loss: 0.3377
# Epoch 16/101
# 38/38 [==============================] - 0s 121us/sample - loss: 0.3367
# Epoch 17/101
# 38/38 [==============================] - 0s 408us/sample - loss: 0.3358
# Epoch 18/101
# 38/38 [==============================] - 0s 227us/sample - loss: 0.3348
# Epoch 19/101
# 38/38 [==============================] - 0s 148us/sample - loss: 0.3339
# Epoch 20/101
# 38/38 [==============================] - 0s 164us/sample - loss: 0.3329
# Epoch 21/101
# 38/38 [==============================] - 0s 173us/sample - loss: 0.3320
# Epoch 22/101
# 38/38 [==============================] - 0s 151us/sample - loss: 0.3311
# Epoch 23/101
# 38/38 [==============================] - 0s 171us/sample - loss: 0.3301
# Epoch 24/101
# 38/38 [==============================] - 0s 152us/sample - loss: 0.3292
# Epoch 25/101
# 38/38 [==============================] - 0s 148us/sample - loss: 0.3283
# Epoch 26/101
# 38/38 [==============================] - 0s 166us/sample - loss: 0.3274
# Epoch 27/101
# 38/38 [==============================] - 0s 153us/sample - loss: 0.3265
# Epoch 28/101
# 38/38 [==============================] - 0s 158us/sample - loss: 0.3255
# Epoch 29/101
# 38/38 [==============================] - 0s 137us/sample - loss: 0.3246
# Epoch 30/101
# 38/38 [==============================] - 0s 126us/sample - loss: 0.3237
# Epoch 31/101
# 38/38 [==============================] - 0s 163us/sample - loss: 0.3228
# Epoch 32/101
# 38/38 [==============================] - 0s 136us/sample - loss: 0.3219
# Epoch 33/101
# 38/38 [==============================] - 0s 163us/sample - loss: 0.3210
# Epoch 34/101
# 38/38 [==============================] - 0s 153us/sample - loss: 0.3201
# Epoch 35/101
# 38/38 [==============================] - 0s 138us/sample - loss: 0.3192
# Epoch 36/101
# 38/38 [==============================] - 0s 155us/sample - loss: 0.3183
# Epoch 37/101
# 38/38 [==============================] - 0s 137us/sample - loss: 0.3174
# Epoch 38/101
# 38/38 [==============================] - 0s 139us/sample - loss: 0.3165
# Epoch 39/101
# 38/38 [==============================] - 0s 162us/sample - loss: 0.3156
# Epoch 40/101
# 38/38 [==============================] - 0s 149us/sample - loss: 0.3148
# Epoch 41/101
# 38/38 [==============================] - 0s 157us/sample - loss: 0.3139
# Epoch 42/101
# 38/38 [==============================] - 0s 149us/sample - loss: 0.3130
# Epoch 43/101
# 38/38 [==============================] - 0s 161us/sample - loss: 0.3121
# Epoch 44/101
# 38/38 [==============================] - 0s 186us/sample - loss: 0.3112
# Epoch 45/101
# 38/38 [==============================] - 0s 138us/sample - loss: 0.3104
# Epoch 46/101
# 38/38 [==============================] - 0s 157us/sample - loss: 0.3095
# Epoch 47/101
# 38/38 [==============================] - 0s 125us/sample - loss: 0.3086
# Epoch 48/101
# 38/38 [==============================] - 0s 137us/sample - loss: 0.3078
# Epoch 49/101
# 38/38 [==============================] - 0s 167us/sample - loss: 0.3069
# Epoch 50/101
# 38/38 [==============================] - 0s 128us/sample - loss: 0.3061
# Epoch 51/101
# 38/38 [==============================] - 0s 124us/sample - loss: 0.3052
# Epoch 52/101
# 38/38 [==============================] - 0s 159us/sample - loss: 0.3044
# Epoch 53/101
# 38/38 [==============================] - 0s 132us/sample - loss: 0.3035
# Epoch 54/101
# 38/38 [==============================] - 0s 140us/sample - loss: 0.3027
# Epoch 55/101
# 38/38 [==============================] - 0s 156us/sample - loss: 0.3018
# Epoch 56/101
# 38/38 [==============================] - 0s 144us/sample - loss: 0.3010
# Epoch 57/101
# 38/38 [==============================] - 0s 150us/sample - loss: 0.3002
# Epoch 58/101
# 38/38 [==============================] - 0s 121us/sample - loss: 0.2993
# Epoch 59/101
# 38/38 [==============================] - 0s 121us/sample - loss: 0.2985
# Epoch 60/101
# 38/38 [==============================] - 0s 174us/sample - loss: 0.2977
# Epoch 61/101
# 38/38 [==============================] - 0s 136us/sample - loss: 0.2968
# Epoch 62/101
# 38/38 [==============================] - 0s 133us/sample - loss: 0.2960
# Epoch 63/101
# 38/38 [==============================] - 0s 149us/sample - loss: 0.2952
# Epoch 64/101
# 38/38 [==============================] - 0s 130us/sample - loss: 0.2944
# Epoch 65/101
# 38/38 [==============================] - 0s 148us/sample - loss: 0.2936
# Epoch 66/101
# 38/38 [==============================] - 0s 150us/sample - loss: 0.2927
# Epoch 67/101
# 38/38 [==============================] - 0s 137us/sample - loss: 0.2919
# Epoch 68/101
# 38/38 [==============================] - 0s 156us/sample - loss: 0.2911
# Epoch 69/101
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2903
# Epoch 70/101
# 38/38 [==============================] - 0s 133us/sample - loss: 0.2895
# Epoch 71/101
# 38/38 [==============================] - 0s 165us/sample - loss: 0.2887
# Epoch 72/101
# 38/38 [==============================] - 0s 139us/sample - loss: 0.2879
# Epoch 73/101
# 38/38 [==============================] - 0s 135us/sample - loss: 0.2871
# Epoch 74/101
# 38/38 [==============================] - 0s 151us/sample - loss: 0.2864
# Epoch 75/101
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2856
# Epoch 76/101
# 38/38 [==============================] - 0s 164us/sample - loss: 0.2848
# Epoch 77/101
# 38/38 [==============================] - 0s 141us/sample - loss: 0.2840
# Epoch 78/101
# 38/38 [==============================] - 0s 130us/sample - loss: 0.2832
# Epoch 79/101
# 38/38 [==============================] - 0s 143us/sample - loss: 0.2824
# Epoch 80/101
# 38/38 [==============================] - 0s 128us/sample - loss: 0.2817
# Epoch 81/101
# 38/38 [==============================] - 0s 125us/sample - loss: 0.2809
# Epoch 82/101
# 38/38 [==============================] - 0s 183us/sample - loss: 0.2801
# Epoch 83/101
# 38/38 [==============================] - 0s 141us/sample - loss: 0.2794
# Epoch 84/101
# 38/38 [==============================] - 0s 130us/sample - loss: 0.2786
# Epoch 85/101
# 38/38 [==============================] - 0s 148us/sample - loss: 0.2778
# Epoch 86/101
# 38/38 [==============================] - 0s 135us/sample - loss: 0.2771
# Epoch 87/101
# 38/38 [==============================] - 0s 155us/sample - loss: 0.2763
# Epoch 88/101
# 38/38 [==============================] - 0s 147us/sample - loss: 0.2756
# Epoch 89/101
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2748
# Epoch 90/101
# 38/38 [==============================] - 0s 152us/sample - loss: 0.2741
# Epoch 91/101
# 38/38 [==============================] - 0s 119us/sample - loss: 0.2733
# Epoch 92/101
# 38/38 [==============================] - 0s 138us/sample - loss: 0.2726
# Epoch 93/101
# 38/38 [==============================] - 0s 145us/sample - loss: 0.2718
# Epoch 94/101
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2711
# Epoch 95/101
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2704
# Epoch 96/101
# 38/38 [==============================] - 0s 125us/sample - loss: 0.2696
# Epoch 97/101
# 38/38 [==============================] - 0s 137us/sample - loss: 0.2689
# Epoch 98/101
# 38/38 [==============================] - 0s 147us/sample - loss: 0.2682
# Epoch 99/101
# 38/38 [==============================] - 0s 137us/sample - loss: 0.2675
# Epoch 100/101
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2667
# Epoch 101/101
# 38/38 [==============================] - 0s 141us/sample - loss: 0.2660
# Model: "model_72"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# col_0 (InputLayer)           [(None, 1)]               0
# _________________________________________________________________
# lattice (Lattice)            (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Train on 38 samples
# Epoch 1/151
# 38/38 [==============================] - 0s 6ms/sample - loss: 0.3512
# Epoch 2/151
# 38/38 [==============================] - 0s 129us/sample - loss: 0.3502
# Epoch 3/151
# 38/38 [==============================] - 0s 132us/sample - loss: 0.3492
# Epoch 4/151
# 38/38 [==============================] - 0s 137us/sample - loss: 0.3482
# Epoch 5/151
# 38/38 [==============================] - 0s 135us/sample - loss: 0.3473
# Epoch 6/151
# 38/38 [==============================] - 0s 124us/sample - loss: 0.3463
# Epoch 7/151
# 38/38 [==============================] - 0s 135us/sample - loss: 0.3453
# Epoch 8/151
# 38/38 [==============================] - 0s 131us/sample - loss: 0.3444
# Epoch 9/151
# 38/38 [==============================] - 0s 154us/sample - loss: 0.3434
# Epoch 10/151
# 38/38 [==============================] - 0s 131us/sample - loss: 0.3424
# Epoch 11/151
# 38/38 [==============================] - 0s 133us/sample - loss: 0.3415
# Epoch 12/151
# 38/38 [==============================] - 0s 140us/sample - loss: 0.3405
# Epoch 13/151
# 38/38 [==============================] - 0s 134us/sample - loss: 0.3396
# Epoch 14/151
# 38/38 [==============================] - 0s 131us/sample - loss: 0.3386
# Epoch 15/151
# 38/38 [==============================] - 0s 156us/sample - loss: 0.3377
# Epoch 16/151
# 38/38 [==============================] - 0s 131us/sample - loss: 0.3367
# Epoch 17/151
# 38/38 [==============================] - 0s 117us/sample - loss: 0.3358
# Epoch 18/151
# 38/38 [==============================] - 0s 144us/sample - loss: 0.3348
# Epoch 19/151
# 38/38 [==============================] - 0s 131us/sample - loss: 0.3339
# Epoch 20/151
# 38/38 [==============================] - 0s 127us/sample - loss: 0.3329
# Epoch 21/151
# 38/38 [==============================] - 0s 155us/sample - loss: 0.3320
# Epoch 22/151
# 38/38 [==============================] - 0s 142us/sample - loss: 0.3311
# Epoch 23/151
# 38/38 [==============================] - 0s 127us/sample - loss: 0.3301
# Epoch 24/151
# 38/38 [==============================] - 0s 130us/sample - loss: 0.3292
# Epoch 25/151
# 38/38 [==============================] - 0s 114us/sample - loss: 0.3283
# Epoch 26/151
# 38/38 [==============================] - 0s 137us/sample - loss: 0.3274
# Epoch 27/151
# 38/38 [==============================] - 0s 132us/sample - loss: 0.3265
# Epoch 28/151
# 38/38 [==============================] - 0s 117us/sample - loss: 0.3255
# Epoch 29/151
# 38/38 [==============================] - 0s 132us/sample - loss: 0.3246
# Epoch 30/151
# 38/38 [==============================] - 0s 131us/sample - loss: 0.3237
# Epoch 31/151
# 38/38 [==============================] - 0s 120us/sample - loss: 0.3228
# Epoch 32/151
# 38/38 [==============================] - 0s 131us/sample - loss: 0.3219
# Epoch 33/151
# 38/38 [==============================] - 0s 154us/sample - loss: 0.3210
# Epoch 34/151
# 38/38 [==============================] - 0s 120us/sample - loss: 0.3201
# Epoch 35/151
# 38/38 [==============================] - 0s 122us/sample - loss: 0.3192
# Epoch 36/151
# 38/38 [==============================] - 0s 134us/sample - loss: 0.3183
# Epoch 37/151
# 38/38 [==============================] - 0s 135us/sample - loss: 0.3174
# Epoch 38/151
# 38/38 [==============================] - 0s 158us/sample - loss: 0.3165
# Epoch 39/151
# 38/38 [==============================] - 0s 142us/sample - loss: 0.3156
# Epoch 40/151
# 38/38 [==============================] - 0s 135us/sample - loss: 0.3148
# Epoch 41/151
# 38/38 [==============================] - 0s 150us/sample - loss: 0.3139
# Epoch 42/151
# 38/38 [==============================] - 0s 124us/sample - loss: 0.3130
# Epoch 43/151
# 38/38 [==============================] - 0s 127us/sample - loss: 0.3121
# Epoch 44/151
# 38/38 [==============================] - 0s 156us/sample - loss: 0.3112
# Epoch 45/151
# 38/38 [==============================] - 0s 140us/sample - loss: 0.3104
# Epoch 46/151
# 38/38 [==============================] - 0s 117us/sample - loss: 0.3095
# Epoch 47/151
# 38/38 [==============================] - 0s 150us/sample - loss: 0.3086
# Epoch 48/151
# 38/38 [==============================] - 0s 122us/sample - loss: 0.3078
# Epoch 49/151
# 38/38 [==============================] - 0s 135us/sample - loss: 0.3069
# Epoch 50/151
# 38/38 [==============================] - 0s 161us/sample - loss: 0.3061
# Epoch 51/151
# 38/38 [==============================] - 0s 137us/sample - loss: 0.3052
# Epoch 52/151
# 38/38 [==============================] - 0s 135us/sample - loss: 0.3044
# Epoch 53/151
# 38/38 [==============================] - 0s 148us/sample - loss: 0.3035
# Epoch 54/151
# 38/38 [==============================] - 0s 129us/sample - loss: 0.3027
# Epoch 55/151
# 38/38 [==============================] - 0s 146us/sample - loss: 0.3018
# Epoch 56/151
# 38/38 [==============================] - 0s 149us/sample - loss: 0.3010
# Epoch 57/151
# 38/38 [==============================] - 0s 135us/sample - loss: 0.3002
# Epoch 58/151
# 38/38 [==============================] - 0s 159us/sample - loss: 0.2993
# Epoch 59/151
# 38/38 [==============================] - 0s 135us/sample - loss: 0.2985
# Epoch 60/151
# 38/38 [==============================] - 0s 146us/sample - loss: 0.2977
# Epoch 61/151
# 38/38 [==============================] - 0s 158us/sample - loss: 0.2968
# Epoch 62/151
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2960
# Epoch 63/151
# 38/38 [==============================] - 0s 141us/sample - loss: 0.2952
# Epoch 64/151
# 38/38 [==============================] - 0s 135us/sample - loss: 0.2944
# Epoch 65/151
# 38/38 [==============================] - 0s 136us/sample - loss: 0.2936
# Epoch 66/151
# 38/38 [==============================] - 0s 170us/sample - loss: 0.2927
# Epoch 67/151
# 38/38 [==============================] - 0s 145us/sample - loss: 0.2919
# Epoch 68/151
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2911
# Epoch 69/151
# 38/38 [==============================] - 0s 161us/sample - loss: 0.2903
# Epoch 70/151
# 38/38 [==============================] - 0s 139us/sample - loss: 0.2895
# Epoch 71/151
# 38/38 [==============================] - 0s 141us/sample - loss: 0.2887
# Epoch 72/151
# 38/38 [==============================] - 0s 171us/sample - loss: 0.2879
# Epoch 73/151
# 38/38 [==============================] - 0s 144us/sample - loss: 0.2871
# Epoch 74/151
# 38/38 [==============================] - 0s 153us/sample - loss: 0.2864
# Epoch 75/151
# 38/38 [==============================] - 0s 135us/sample - loss: 0.2856
# Epoch 76/151
# 38/38 [==============================] - 0s 135us/sample - loss: 0.2848
# Epoch 77/151
# 38/38 [==============================] - 0s 175us/sample - loss: 0.2840
# Epoch 78/151
# 38/38 [==============================] - 0s 146us/sample - loss: 0.2832
# Epoch 79/151
# 38/38 [==============================] - 0s 151us/sample - loss: 0.2824
# Epoch 80/151
# 38/38 [==============================] - 0s 137us/sample - loss: 0.2817
# Epoch 81/151
# 38/38 [==============================] - 0s 143us/sample - loss: 0.2809
# Epoch 82/151
# 38/38 [==============================] - 0s 174us/sample - loss: 0.2801
# Epoch 83/151
# 38/38 [==============================] - 0s 137us/sample - loss: 0.2794
# Epoch 84/151
# 38/38 [==============================] - 0s 130us/sample - loss: 0.2786
# Epoch 85/151
# 38/38 [==============================] - 0s 154us/sample - loss: 0.2778
# Epoch 86/151
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2771
# Epoch 87/151
# 38/38 [==============================] - 0s 150us/sample - loss: 0.2763
# Epoch 88/151
# 38/38 [==============================] - 0s 145us/sample - loss: 0.2756
# Epoch 89/151
# 38/38 [==============================] - 0s 134us/sample - loss: 0.2748
# Epoch 90/151
# 38/38 [==============================] - 0s 152us/sample - loss: 0.2741
# Epoch 91/151
# 38/38 [==============================] - 0s 135us/sample - loss: 0.2733
# Epoch 92/151
# 38/38 [==============================] - 0s 128us/sample - loss: 0.2726
# Epoch 93/151
# 38/38 [==============================] - 0s 166us/sample - loss: 0.2718
# Epoch 94/151
# 38/38 [==============================] - 0s 139us/sample - loss: 0.2711
# Epoch 95/151
# 38/38 [==============================] - 0s 131us/sample - loss: 0.2704
# Epoch 96/151
# 38/38 [==============================] - 0s 158us/sample - loss: 0.2696
# Epoch 97/151
# 38/38 [==============================] - 0s 137us/sample - loss: 0.2689
# Epoch 98/151
# 38/38 [==============================] - 0s 170us/sample - loss: 0.2682
# Epoch 99/151
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2675
# Epoch 100/151
# 38/38 [==============================] - 0s 131us/sample - loss: 0.2667
# Epoch 101/151
# 38/38 [==============================] - 0s 139us/sample - loss: 0.2660
# Epoch 102/151
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2653
# Epoch 103/151
# 38/38 [==============================] - 0s 132us/sample - loss: 0.2646
# Epoch 104/151
# 38/38 [==============================] - 0s 167us/sample - loss: 0.2639
# Epoch 105/151
# 38/38 [==============================] - 0s 143us/sample - loss: 0.2632
# Epoch 106/151
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2625
# Epoch 107/151
# 38/38 [==============================] - 0s 146us/sample - loss: 0.2617
# Epoch 108/151
# 38/38 [==============================] - 0s 146us/sample - loss: 0.2610
# Epoch 109/151
# 38/38 [==============================] - 0s 164us/sample - loss: 0.2603
# Epoch 110/151
# 38/38 [==============================] - 0s 139us/sample - loss: 0.2597
# Epoch 111/151
# 38/38 [==============================] - 0s 134us/sample - loss: 0.2590
# Epoch 112/151
# 38/38 [==============================] - 0s 151us/sample - loss: 0.2583
# Epoch 113/151
# 38/38 [==============================] - 0s 134us/sample - loss: 0.2576
# Epoch 114/151
# 38/38 [==============================] - 0s 173us/sample - loss: 0.2569
# Epoch 115/151
# 38/38 [==============================] - 0s 143us/sample - loss: 0.2562
# Epoch 116/151
# 38/38 [==============================] - 0s 143us/sample - loss: 0.2555
# Epoch 117/151
# 38/38 [==============================] - 0s 150us/sample - loss: 0.2548
# Epoch 118/151
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2542
# Epoch 119/151
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2535
# Epoch 120/151
# 38/38 [==============================] - 0s 163us/sample - loss: 0.2528
# Epoch 121/151
# 38/38 [==============================] - 0s 147us/sample - loss: 0.2521
# Epoch 122/151
# 38/38 [==============================] - 0s 153us/sample - loss: 0.2515
# Epoch 123/151
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2508
# Epoch 124/151
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2502
# Epoch 125/151
# 38/38 [==============================] - 0s 166us/sample - loss: 0.2495
# Epoch 126/151
# 38/38 [==============================] - 0s 143us/sample - loss: 0.2488
# Epoch 127/151
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2482
# Epoch 128/151
# 38/38 [==============================] - 0s 146us/sample - loss: 0.2475
# Epoch 129/151
# 38/38 [==============================] - 0s 129us/sample - loss: 0.2469
# Epoch 130/151
# 38/38 [==============================] - 0s 153us/sample - loss: 0.2462
# Epoch 131/151
# 38/38 [==============================] - 0s 153us/sample - loss: 0.2456
# Epoch 132/151
# 38/38 [==============================] - 0s 136us/sample - loss: 0.2449
# Epoch 133/151
# 38/38 [==============================] - 0s 152us/sample - loss: 0.2443
# Epoch 134/151
# 38/38 [==============================] - 0s 136us/sample - loss: 0.2437
# Epoch 135/151
# 38/38 [==============================] - 0s 134us/sample - loss: 0.2430
# Epoch 136/151
# 38/38 [==============================] - 0s 167us/sample - loss: 0.2424
# Epoch 137/151
# 38/38 [==============================] - 0s 151us/sample - loss: 0.2418
# Epoch 138/151
# 38/38 [==============================] - 0s 147us/sample - loss: 0.2411
# Epoch 139/151
# 38/38 [==============================] - 0s 141us/sample - loss: 0.2405
# Epoch 140/151
# 38/38 [==============================] - 0s 137us/sample - loss: 0.2399
# Epoch 141/151
# 38/38 [==============================] - 0s 163us/sample - loss: 0.2393
# Epoch 142/151
# 38/38 [==============================] - 0s 141us/sample - loss: 0.2386
# Epoch 143/151
# 38/38 [==============================] - 0s 134us/sample - loss: 0.2380
# Epoch 144/151
# 38/38 [==============================] - 0s 144us/sample - loss: 0.2374
# Epoch 145/151
# 38/38 [==============================] - 0s 131us/sample - loss: 0.2368
# Epoch 146/151
# 38/38 [==============================] - 0s 144us/sample - loss: 0.2362
# Epoch 147/151
# 38/38 [==============================] - 0s 168us/sample - loss: 0.2356
# Epoch 148/151
# 38/38 [==============================] - 0s 139us/sample - loss: 0.2350
# Epoch 149/151
# 38/38 [==============================] - 0s 141us/sample - loss: 0.2344
# Epoch 150/151
# 38/38 [==============================] - 0s 141us/sample - loss: 0.2338
# Epoch 151/151
# 38/38 [==============================] - 0s 136us/sample - loss: 0.2332
# Model: "model_73"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# col_0 (InputLayer)           [(None, 1)]               0
# _________________________________________________________________
# lattice (Lattice)            (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Train on 38 samples
# Epoch 1/201
# 38/38 [==============================] - 0s 6ms/sample - loss: 0.3512
# Epoch 2/201
# 38/38 [==============================] - 0s 124us/sample - loss: 0.3502
# Epoch 3/201
# 38/38 [==============================] - 0s 131us/sample - loss: 0.3492
# Epoch 4/201
# 38/38 [==============================] - 0s 120us/sample - loss: 0.3482
# Epoch 5/201
# 38/38 [==============================] - 0s 131us/sample - loss: 0.3473
# Epoch 6/201
# 38/38 [==============================] - 0s 125us/sample - loss: 0.3463
# Epoch 7/201
# 38/38 [==============================] - 0s 153us/sample - loss: 0.3453
# Epoch 8/201
# 38/38 [==============================] - 0s 132us/sample - loss: 0.3444
# Epoch 9/201
# 38/38 [==============================] - 0s 126us/sample - loss: 0.3434
# Epoch 10/201
# 38/38 [==============================] - 0s 139us/sample - loss: 0.3424
# Epoch 11/201
# 38/38 [==============================] - 0s 128us/sample - loss: 0.3415
# Epoch 12/201
# 38/38 [==============================] - 0s 119us/sample - loss: 0.3405
# Epoch 13/201
# 38/38 [==============================] - 0s 140us/sample - loss: 0.3396
# Epoch 14/201
# 38/38 [==============================] - 0s 132us/sample - loss: 0.3386
# Epoch 15/201
# 38/38 [==============================] - 0s 122us/sample - loss: 0.3377
# Epoch 16/201
# 38/38 [==============================] - 0s 140us/sample - loss: 0.3367
# Epoch 17/201
# 38/38 [==============================] - 0s 131us/sample - loss: 0.3358
# Epoch 18/201
# 38/38 [==============================] - 0s 117us/sample - loss: 0.3348
# Epoch 19/201
# 38/38 [==============================] - 0s 147us/sample - loss: 0.3339
# Epoch 20/201
# 38/38 [==============================] - 0s 135us/sample - loss: 0.3329
# Epoch 21/201
# 38/38 [==============================] - 0s 121us/sample - loss: 0.3320
# Epoch 22/201
# 38/38 [==============================] - 0s 129us/sample - loss: 0.3311
# Epoch 23/201
# 38/38 [==============================] - 0s 125us/sample - loss: 0.3301
# Epoch 24/201
# 38/38 [==============================] - 0s 125us/sample - loss: 0.3292
# Epoch 25/201
# 38/38 [==============================] - 0s 139us/sample - loss: 0.3283
# Epoch 26/201
# 38/38 [==============================] - 0s 133us/sample - loss: 0.3274
# Epoch 27/201
# 38/38 [==============================] - 0s 118us/sample - loss: 0.3265
# Epoch 28/201
# 38/38 [==============================] - 0s 145us/sample - loss: 0.3255
# Epoch 29/201
# 38/38 [==============================] - 0s 124us/sample - loss: 0.3246
# Epoch 30/201
# 38/38 [==============================] - 0s 125us/sample - loss: 0.3237
# Epoch 31/201
# 38/38 [==============================] - 0s 151us/sample - loss: 0.3228
# Epoch 32/201
# 38/38 [==============================] - 0s 131us/sample - loss: 0.3219
# Epoch 33/201
# 38/38 [==============================] - 0s 115us/sample - loss: 0.3210
# Epoch 34/201
# 38/38 [==============================] - 0s 136us/sample - loss: 0.3201
# Epoch 35/201
# 38/38 [==============================] - 0s 128us/sample - loss: 0.3192
# Epoch 36/201
# 38/38 [==============================] - 0s 118us/sample - loss: 0.3183
# Epoch 37/201
# 38/38 [==============================] - 0s 152us/sample - loss: 0.3174
# Epoch 38/201
# 38/38 [==============================] - 0s 144us/sample - loss: 0.3165
# Epoch 39/201
# 38/38 [==============================] - 0s 134us/sample - loss: 0.3156
# Epoch 40/201
# 38/38 [==============================] - 0s 147us/sample - loss: 0.3148
# Epoch 41/201
# 38/38 [==============================] - 0s 137us/sample - loss: 0.3139
# Epoch 42/201
# 38/38 [==============================] - 0s 143us/sample - loss: 0.3130
# Epoch 43/201
# 38/38 [==============================] - 0s 150us/sample - loss: 0.3121
# Epoch 44/201
# 38/38 [==============================] - 0s 141us/sample - loss: 0.3112
# Epoch 45/201
# 38/38 [==============================] - 0s 138us/sample - loss: 0.3104
# Epoch 46/201
# 38/38 [==============================] - 0s 136us/sample - loss: 0.3095
# Epoch 47/201
# 38/38 [==============================] - 0s 133us/sample - loss: 0.3086
# Epoch 48/201
# 38/38 [==============================] - 0s 167us/sample - loss: 0.3078
# Epoch 49/201
# 38/38 [==============================] - 0s 145us/sample - loss: 0.3069
# Epoch 50/201
# 38/38 [==============================] - 0s 130us/sample - loss: 0.3061
# Epoch 51/201
# 38/38 [==============================] - 0s 129us/sample - loss: 0.3052
# Epoch 52/201
# 38/38 [==============================] - 0s 125us/sample - loss: 0.3044
# Epoch 53/201
# 38/38 [==============================] - 0s 137us/sample - loss: 0.3035
# Epoch 54/201
# 38/38 [==============================] - 0s 154us/sample - loss: 0.3027
# Epoch 55/201
# 38/38 [==============================] - 0s 144us/sample - loss: 0.3018
# Epoch 56/201
# 38/38 [==============================] - 0s 141us/sample - loss: 0.3010
# Epoch 57/201
# 38/38 [==============================] - 0s 142us/sample - loss: 0.3002
# Epoch 58/201
# 38/38 [==============================] - 0s 135us/sample - loss: 0.2993
# Epoch 59/201
# 38/38 [==============================] - 0s 154us/sample - loss: 0.2985
# Epoch 60/201
# 38/38 [==============================] - 0s 147us/sample - loss: 0.2977
# Epoch 61/201
# 38/38 [==============================] - 0s 136us/sample - loss: 0.2968
# Epoch 62/201
# 38/38 [==============================] - 0s 152us/sample - loss: 0.2960
# Epoch 63/201
# 38/38 [==============================] - 0s 132us/sample - loss: 0.2952
# Epoch 64/201
# 38/38 [==============================] - 0s 144us/sample - loss: 0.2944
# Epoch 65/201
# 38/38 [==============================] - 0s 160us/sample - loss: 0.2936
# Epoch 66/201
# 38/38 [==============================] - 0s 146us/sample - loss: 0.2927
# Epoch 67/201
# 38/38 [==============================] - 0s 154us/sample - loss: 0.2919
# Epoch 68/201
# 38/38 [==============================] - 0s 143us/sample - loss: 0.2911
# Epoch 69/201
# 38/38 [==============================] - 0s 149us/sample - loss: 0.2903
# Epoch 70/201
# 38/38 [==============================] - 0s 154us/sample - loss: 0.2895
# Epoch 71/201
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2887
# Epoch 72/201
# 38/38 [==============================] - 0s 128us/sample - loss: 0.2879
# Epoch 73/201
# 38/38 [==============================] - 0s 144us/sample - loss: 0.2871
# Epoch 74/201
# 38/38 [==============================] - 0s 127us/sample - loss: 0.2864
# Epoch 75/201
# 38/38 [==============================] - 0s 144us/sample - loss: 0.2856
# Epoch 76/201
# 38/38 [==============================] - 0s 147us/sample - loss: 0.2848
# Epoch 77/201
# 38/38 [==============================] - 0s 135us/sample - loss: 0.2840
# Epoch 78/201
# 38/38 [==============================] - 0s 151us/sample - loss: 0.2832
# Epoch 79/201
# 38/38 [==============================] - 0s 138us/sample - loss: 0.2824
# Epoch 80/201
# 38/38 [==============================] - 0s 135us/sample - loss: 0.2817
# Epoch 81/201
# 38/38 [==============================] - 0s 168us/sample - loss: 0.2809
# Epoch 82/201
# 38/38 [==============================] - 0s 143us/sample - loss: 0.2801
# Epoch 83/201
# 38/38 [==============================] - 0s 138us/sample - loss: 0.2794
# Epoch 84/201
# 38/38 [==============================] - 0s 147us/sample - loss: 0.2786
# Epoch 85/201
# 38/38 [==============================] - 0s 134us/sample - loss: 0.2778
# Epoch 86/201
# 38/38 [==============================] - 0s 150us/sample - loss: 0.2771
# Epoch 87/201
# 38/38 [==============================] - 0s 146us/sample - loss: 0.2763
# Epoch 88/201
# 38/38 [==============================] - 0s 141us/sample - loss: 0.2756
# Epoch 89/201
# 38/38 [==============================] - 0s 148us/sample - loss: 0.2748
# Epoch 90/201
# 38/38 [==============================] - 0s 139us/sample - loss: 0.2741
# Epoch 91/201
# 38/38 [==============================] - 0s 160us/sample - loss: 0.2733
# Epoch 92/201
# 38/38 [==============================] - 0s 158us/sample - loss: 0.2726
# Epoch 93/201
# 38/38 [==============================] - 0s 135us/sample - loss: 0.2718
# Epoch 94/201
# 38/38 [==============================] - 0s 136us/sample - loss: 0.2711
# Epoch 95/201
# 38/38 [==============================] - 0s 141us/sample - loss: 0.2704
# Epoch 96/201
# 38/38 [==============================] - 0s 137us/sample - loss: 0.2696
# Epoch 97/201
# 38/38 [==============================] - 0s 172us/sample - loss: 0.2689
# Epoch 98/201
# 38/38 [==============================] - 0s 146us/sample - loss: 0.2682
# Epoch 99/201
# 38/38 [==============================] - 0s 130us/sample - loss: 0.2675
# Epoch 100/201
# 38/38 [==============================] - 0s 154us/sample - loss: 0.2667
# Epoch 101/201
# 38/38 [==============================] - 0s 147us/sample - loss: 0.2660
# Epoch 102/201
# 38/38 [==============================] - 0s 154us/sample - loss: 0.2653
# Epoch 103/201
# 38/38 [==============================] - 0s 153us/sample - loss: 0.2646
# Epoch 104/201
# 38/38 [==============================] - 0s 136us/sample - loss: 0.2639
# Epoch 105/201
# 38/38 [==============================] - 0s 153us/sample - loss: 0.2632
# Epoch 106/201
# 38/38 [==============================] - 0s 134us/sample - loss: 0.2625
# Epoch 107/201
# 38/38 [==============================] - 0s 144us/sample - loss: 0.2617
# Epoch 108/201
# 38/38 [==============================] - 0s 149us/sample - loss: 0.2610
# Epoch 109/201
# 38/38 [==============================] - 0s 141us/sample - loss: 0.2603
# Epoch 110/201
# 38/38 [==============================] - 0s 127us/sample - loss: 0.2597
# Epoch 111/201
# 38/38 [==============================] - 0s 147us/sample - loss: 0.2590
# Epoch 112/201
# 38/38 [==============================] - 0s 134us/sample - loss: 0.2583
# Epoch 113/201
# 38/38 [==============================] - 0s 165us/sample - loss: 0.2576
# Epoch 114/201
# 38/38 [==============================] - 0s 156us/sample - loss: 0.2569
# Epoch 115/201
# 38/38 [==============================] - 0s 131us/sample - loss: 0.2562
# Epoch 116/201
# 38/38 [==============================] - 0s 145us/sample - loss: 0.2555
# Epoch 117/201
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2548
# Epoch 118/201
# 38/38 [==============================] - 0s 146us/sample - loss: 0.2542
# Epoch 119/201
# 38/38 [==============================] - 0s 156us/sample - loss: 0.2535
# Epoch 120/201
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2528
# Epoch 121/201
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2521
# Epoch 122/201
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2515
# Epoch 123/201
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2508
# Epoch 124/201
# 38/38 [==============================] - 0s 168us/sample - loss: 0.2502
# Epoch 125/201
# 38/38 [==============================] - 0s 145us/sample - loss: 0.2495
# Epoch 126/201
# 38/38 [==============================] - 0s 133us/sample - loss: 0.2488
# Epoch 127/201
# 38/38 [==============================] - 0s 155us/sample - loss: 0.2482
# Epoch 128/201
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2475
# Epoch 129/201
# 38/38 [==============================] - 0s 143us/sample - loss: 0.2469
# Epoch 130/201
# 38/38 [==============================] - 0s 170us/sample - loss: 0.2462
# Epoch 131/201
# 38/38 [==============================] - 0s 134us/sample - loss: 0.2456
# Epoch 132/201
# 38/38 [==============================] - 0s 149us/sample - loss: 0.2449
# Epoch 133/201
# 38/38 [==============================] - 0s 143us/sample - loss: 0.2443
# Epoch 134/201
# 38/38 [==============================] - 0s 135us/sample - loss: 0.2437
# Epoch 135/201
# 38/38 [==============================] - 0s 163us/sample - loss: 0.2430
# Epoch 136/201
# 38/38 [==============================] - 0s 146us/sample - loss: 0.2424
# Epoch 137/201
# 38/38 [==============================] - 0s 135us/sample - loss: 0.2418
# Epoch 138/201
# 38/38 [==============================] - 0s 147us/sample - loss: 0.2411
# Epoch 139/201
# 38/38 [==============================] - 0s 139us/sample - loss: 0.2405
# Epoch 140/201
# 38/38 [==============================] - 0s 161us/sample - loss: 0.2399
# Epoch 141/201
# 38/38 [==============================] - 0s 129us/sample - loss: 0.2393
# Epoch 142/201
# 38/38 [==============================] - 0s 145us/sample - loss: 0.2386
# Epoch 143/201
# 38/38 [==============================] - 0s 160us/sample - loss: 0.2380
# Epoch 144/201
# 38/38 [==============================] - 0s 122us/sample - loss: 0.2374
# Epoch 145/201
# 38/38 [==============================] - 0s 151us/sample - loss: 0.2368
# Epoch 146/201
# 38/38 [==============================] - 0s 173us/sample - loss: 0.2362
# Epoch 147/201
# 38/38 [==============================] - 0s 137us/sample - loss: 0.2356
# Epoch 148/201
# 38/38 [==============================] - 0s 143us/sample - loss: 0.2350
# Epoch 149/201
# 38/38 [==============================] - 0s 149us/sample - loss: 0.2344
# Epoch 150/201
# 38/38 [==============================] - 0s 138us/sample - loss: 0.2338
# Epoch 151/201
# 38/38 [==============================] - 0s 164us/sample - loss: 0.2332
# Epoch 152/201
# 38/38 [==============================] - 0s 149us/sample - loss: 0.2326
# Epoch 153/201
# 38/38 [==============================] - 0s 130us/sample - loss: 0.2320
# Epoch 154/201
# 38/38 [==============================] - 0s 164us/sample - loss: 0.2314
# Epoch 155/201
# 38/38 [==============================] - 0s 134us/sample - loss: 0.2308
# Epoch 156/201
# 38/38 [==============================] - 0s 152us/sample - loss: 0.2302
# Epoch 157/201
# 38/38 [==============================] - 0s 147us/sample - loss: 0.2296
# Epoch 158/201
# 38/38 [==============================] - 0s 135us/sample - loss: 0.2290
# Epoch 159/201
# 38/38 [==============================] - 0s 149us/sample - loss: 0.2284
# Epoch 160/201
# 38/38 [==============================] - 0s 135us/sample - loss: 0.2279
# Epoch 161/201
# 38/38 [==============================] - 0s 138us/sample - loss: 0.2273
# Epoch 162/201
# 38/38 [==============================] - 0s 176us/sample - loss: 0.2267
# Epoch 163/201
# 38/38 [==============================] - 0s 144us/sample - loss: 0.2261
# Epoch 164/201
# 38/38 [==============================] - 0s 141us/sample - loss: 0.2256
# Epoch 165/201
# 38/38 [==============================] - 0s 147us/sample - loss: 0.2250
# Epoch 166/201
# 38/38 [==============================] - 0s 133us/sample - loss: 0.2244
# Epoch 167/201
# 38/38 [==============================] - 0s 152us/sample - loss: 0.2239
# Epoch 168/201
# 38/38 [==============================] - 0s 149us/sample - loss: 0.2233
# Epoch 169/201
# 38/38 [==============================] - 0s 137us/sample - loss: 0.2228
# Epoch 170/201
# 38/38 [==============================] - 0s 145us/sample - loss: 0.2222
# Epoch 171/201
# 38/38 [==============================] - 0s 135us/sample - loss: 0.2216
# Epoch 172/201
# 38/38 [==============================] - 0s 152us/sample - loss: 0.2211
# Epoch 173/201
# 38/38 [==============================] - 0s 155us/sample - loss: 0.2205
# Epoch 174/201
# 38/38 [==============================] - 0s 134us/sample - loss: 0.2200
# Epoch 175/201
# 38/38 [==============================] - 0s 148us/sample - loss: 0.2194
# Epoch 176/201
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2189
# Epoch 177/201
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2184
# Epoch 178/201
# 38/38 [==============================] - 0s 169us/sample - loss: 0.2178
# Epoch 179/201
# 38/38 [==============================] - 0s 147us/sample - loss: 0.2173
# Epoch 180/201
# 38/38 [==============================] - 0s 131us/sample - loss: 0.2167
# Epoch 181/201
# 38/38 [==============================] - 0s 156us/sample - loss: 0.2162
# Epoch 182/201
# 38/38 [==============================] - 0s 138us/sample - loss: 0.2157
# Epoch 183/201
# 38/38 [==============================] - 0s 162us/sample - loss: 0.2151
# Epoch 184/201
# 38/38 [==============================] - 0s 151us/sample - loss: 0.2146
# Epoch 185/201
# 38/38 [==============================] - 0s 135us/sample - loss: 0.2141
# Epoch 186/201
# 38/38 [==============================] - 0s 148us/sample - loss: 0.2136
# Epoch 187/201
# 38/38 [==============================] - 0s 136us/sample - loss: 0.2130
# Epoch 188/201
# 38/38 [==============================] - 0s 145us/sample - loss: 0.2125
# Epoch 189/201
# 38/38 [==============================] - 0s 157us/sample - loss: 0.2120
# Epoch 190/201
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2115
# Epoch 191/201
# 38/38 [==============================] - 0s 158us/sample - loss: 0.2110
# Epoch 192/201
# 38/38 [==============================] - 0s 144us/sample - loss: 0.2105
# Epoch 193/201
# 38/38 [==============================] - 0s 132us/sample - loss: 0.2100
# Epoch 194/201
# 38/38 [==============================] - 0s 173us/sample - loss: 0.2095
# Epoch 195/201
# 38/38 [==============================] - 0s 151us/sample - loss: 0.2090
# Epoch 196/201
# 38/38 [==============================] - 0s 131us/sample - loss: 0.2085
# Epoch 197/201
# 38/38 [==============================] - 0s 150us/sample - loss: 0.2080
# Epoch 198/201
# 38/38 [==============================] - 0s 135us/sample - loss: 0.2075
# Epoch 199/201
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2070
# Epoch 200/201
# 38/38 [==============================] - 0s 155us/sample - loss: 0.2065
# Epoch 201/201
# 38/38 [==============================] - 0s 136us/sample - loss: 0.2060
# Model: "model_74"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# col_0 (InputLayer)           [(None, 1)]               0
# _________________________________________________________________
# lattice (Lattice)            (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Train on 38 samples
# Epoch 1/251
# 38/38 [==============================] - 0s 6ms/sample - loss: 0.3512
# Epoch 2/251
# 38/38 [==============================] - 0s 136us/sample - loss: 0.3502
# Epoch 3/251
# 38/38 [==============================] - 0s 129us/sample - loss: 0.3492
# Epoch 4/251
# 38/38 [==============================] - 0s 120us/sample - loss: 0.3482
# Epoch 5/251
# 38/38 [==============================] - 0s 133us/sample - loss: 0.3473
# Epoch 6/251
# 38/38 [==============================] - 0s 151us/sample - loss: 0.3463
# Epoch 7/251
# 38/38 [==============================] - 0s 128us/sample - loss: 0.3453
# Epoch 8/251
# 38/38 [==============================] - 0s 125us/sample - loss: 0.3444
# Epoch 9/251
# ...
# Epoch 66/251
# 38/38 [==============================] - 0s 149us/sample - loss: 0.2927
# Epoch 67/251
# 38/38 [==============================] - 0s 143us/sample - loss: 0.2919
# Epoch 68/251
# 38/38 [==============================] - 0s 144us/sample - loss: 0.2911
# Epoch 69/251
# 38/38 [==============================] - 0s 153us/sample - loss: 0.2903
# Epoch 70/251
# 38/38 [==============================] - 0s 153us/sample - loss: 0.2895
# Epoch 71/251
# 38/38 [==============================] - 0s 138us/sample - loss: 0.2887
# Epoch 72/251
# 38/38 [==============================] - 0s 133us/sample - loss: 0.2879
# Epoch 73/251
# 38/38 [==============================] - 0s 132us/sample - loss: 0.2871
# Epoch 74/251
# 38/38 [==============================] - 0s 148us/sample - loss: 0.2864
# Epoch 75/251
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2856
# Epoch 76/251
# 38/38 [==============================] - 0s 130us/sample - loss: 0.2848
# Epoch 77/251
# 38/38 [==============================] - 0s 146us/sample - loss: 0.2840
# Epoch 78/251
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2832
# Epoch 79/251
# 38/38 [==============================] - 0s 138us/sample - loss: 0.2824
# Epoch 80/251
# 38/38 [==============================] - 0s 148us/sample - loss: 0.2817
# Epoch 81/251
# 38/38 [==============================] - 0s 136us/sample - loss: 0.2809
# Epoch 82/251
# 38/38 [==============================] - 0s 135us/sample - loss: 0.2801
# Epoch 83/251
# 38/38 [==============================] - 0s 138us/sample - loss: 0.2794
# Epoch 84/251
# 38/38 [==============================] - 0s 136us/sample - loss: 0.2786
# Epoch 85/251
# 38/38 [==============================] - 0s 144us/sample - loss: 0.2778
# Epoch 86/251
# 38/38 [==============================] - 0s 136us/sample - loss: 0.2771
# Epoch 87/251
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2763
# Epoch 88/251
# 38/38 [==============================] - 0s 138us/sample - loss: 0.2756
# Epoch 89/251
# 38/38 [==============================] - 0s 134us/sample - loss: 0.2748
# Epoch 90/251
# 38/38 [==============================] - 0s 148us/sample - loss: 0.2741
# Epoch 91/251
# 38/38 [==============================] - 0s 165us/sample - loss: 0.2733
# Epoch 92/251
# 38/38 [==============================] - 0s 139us/sample - loss: 0.2726
# Epoch 93/251
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2718
# Epoch 94/251
# 38/38 [==============================] - 0s 147us/sample - loss: 0.2711
# Epoch 95/251
# 38/38 [==============================] - 0s 134us/sample - loss: 0.2704
# Epoch 96/251
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2696
# Epoch 97/251
# 38/38 [==============================] - 0s 159us/sample - loss: 0.2689
# Epoch 98/251
# 38/38 [==============================] - 0s 135us/sample - loss: 0.2682
# Epoch 99/251
# 38/38 [==============================] - 0s 143us/sample - loss: 0.2675
# Epoch 100/251
# 38/38 [==============================] - 0s 146us/sample - loss: 0.2667
# Epoch 101/251
# 38/38 [==============================] - 0s 133us/sample - loss: 0.2660
# Epoch 102/251
# 38/38 [==============================] - 0s 148us/sample - loss: 0.2653
# Epoch 103/251
# 38/38 [==============================] - 0s 147us/sample - loss: 0.2646
# Epoch 104/251
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2639
# Epoch 105/251
# 38/38 [==============================] - 0s 158us/sample - loss: 0.2632
# Epoch 106/251
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2625
# Epoch 107/251
# 38/38 [==============================] - 0s 150us/sample - loss: 0.2617
# Epoch 108/251
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2610
# Epoch 109/251
# 38/38 [==============================] - 0s 137us/sample - loss: 0.2603
# Epoch 110/251
# 38/38 [==============================] - 0s 144us/sample - loss: 0.2597
# Epoch 111/251
# 38/38 [==============================] - 0s 134us/sample - loss: 0.2590
# Epoch 112/251
# 38/38 [==============================] - 0s 131us/sample - loss: 0.2583
# Epoch 113/251
# 38/38 [==============================] - 0s 172us/sample - loss: 0.2576
# Epoch 114/251
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2569
# Epoch 115/251
# 38/38 [==============================] - 0s 129us/sample - loss: 0.2562
# Epoch 116/251
# 38/38 [==============================] - 0s 132us/sample - loss: 0.2555
# Epoch 117/251
# 38/38 [==============================] - 0s 141us/sample - loss: 0.2548
# Epoch 118/251
# 38/38 [==============================] - 0s 135us/sample - loss: 0.2542
# Epoch 119/251
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2535
# Epoch 120/251
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2528
# Epoch 121/251
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2521
# Epoch 122/251
# 38/38 [==============================] - 0s 139us/sample - loss: 0.2515
# Epoch 123/251
# 38/38 [==============================] - 0s 146us/sample - loss: 0.2508
# Epoch 124/251
# 38/38 [==============================] - 0s 149us/sample - loss: 0.2502
# Epoch 125/251
# 38/38 [==============================] - 0s 149us/sample - loss: 0.2495
# Epoch 126/251
# 38/38 [==============================] - 0s 126us/sample - loss: 0.2488
# Epoch 127/251
# 38/38 [==============================] - 0s 141us/sample - loss: 0.2482
# Epoch 128/251
# 38/38 [==============================] - 0s 133us/sample - loss: 0.2475
# Epoch 129/251
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2469
# Epoch 130/251
# 38/38 [==============================] - 0s 162us/sample - loss: 0.2462
# Epoch 131/251
# 38/38 [==============================] - 0s 137us/sample - loss: 0.2456
# Epoch 132/251
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2449
# Epoch 133/251
# 38/38 [==============================] - 0s 136us/sample - loss: 0.2443
# Epoch 134/251
# 38/38 [==============================] - 0s 137us/sample - loss: 0.2437
# Epoch 135/251
# 38/38 [==============================] - 0s 146us/sample - loss: 0.2430
# Epoch 136/251
# 38/38 [==============================] - 0s 143us/sample - loss: 0.2424
# Epoch 137/251
# 38/38 [==============================] - 0s 134us/sample - loss: 0.2418
# Epoch 138/251
# 38/38 [==============================] - 0s 152us/sample - loss: 0.2411
# Epoch 139/251
# 38/38 [==============================] - 0s 132us/sample - loss: 0.2405
# Epoch 140/251
# 38/38 [==============================] - 0s 160us/sample - loss: 0.2399
# Epoch 141/251
# 38/38 [==============================] - 0s 143us/sample - loss: 0.2393
# Epoch 142/251
# 38/38 [==============================] - 0s 129us/sample - loss: 0.2386
# Epoch 143/251
# 38/38 [==============================] - 0s 152us/sample - loss: 0.2380
# Epoch 144/251
# 38/38 [==============================] - 0s 143us/sample - loss: 0.2374
# Epoch 145/251
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2368
# Epoch 146/251
# 38/38 [==============================] - 0s 156us/sample - loss: 0.2362
# Epoch 147/251
# 38/38 [==============================] - 0s 136us/sample - loss: 0.2356
# Epoch 148/251
# 38/38 [==============================] - 0s 133us/sample - loss: 0.2350
# Epoch 149/251
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2344
# Epoch 150/251
# 38/38 [==============================] - 0s 133us/sample - loss: 0.2338
# Epoch 151/251
# 38/38 [==============================] - 0s 138us/sample - loss: 0.2332
# Epoch 152/251
# 38/38 [==============================] - 0s 152us/sample - loss: 0.2326
# Epoch 153/251
# 38/38 [==============================] - 0s 143us/sample - loss: 0.2320
# Epoch 154/251
# 38/38 [==============================] - 0s 138us/sample - loss: 0.2314
# Epoch 155/251
# 38/38 [==============================] - 0s 133us/sample - loss: 0.2308
# Epoch 156/251
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2302
# Epoch 157/251
# 38/38 [==============================] - 0s 139us/sample - loss: 0.2296
# Epoch 158/251
# 38/38 [==============================] - 0s 148us/sample - loss: 0.2290
# Epoch 159/251
# 38/38 [==============================] - 0s 134us/sample - loss: 0.2284
# Epoch 160/251
# 38/38 [==============================] - 0s 138us/sample - loss: 0.2279
# Epoch 161/251
# 38/38 [==============================] - 0s 127us/sample - loss: 0.2273
# Epoch 162/251
# 38/38 [==============================] - 0s 156us/sample - loss: 0.2267
# Epoch 163/251
# 38/38 [==============================] - 0s 157us/sample - loss: 0.2261
# Epoch 164/251
# 38/38 [==============================] - 0s 131us/sample - loss: 0.2256
# Epoch 165/251
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2250
# Epoch 166/251
# 38/38 [==============================] - 0s 141us/sample - loss: 0.2244
# Epoch 167/251
# 38/38 [==============================] - 0s 138us/sample - loss: 0.2239
# Epoch 168/251
# 38/38 [==============================] - 0s 148us/sample - loss: 0.2233
# Epoch 169/251
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2228
# Epoch 170/251
# 38/38 [==============================] - 0s 137us/sample - loss: 0.2222
# Epoch 171/251
# 38/38 [==============================] - 0s 151us/sample - loss: 0.2216
# Epoch 172/251
# 38/38 [==============================] - 0s 129us/sample - loss: 0.2211
# Epoch 173/251
# 38/38 [==============================] - 0s 159us/sample - loss: 0.2205
# Epoch 174/251
# 38/38 [==============================] - 0s 150us/sample - loss: 0.2200
# Epoch 175/251
# 38/38 [==============================] - 0s 138us/sample - loss: 0.2194
# Epoch 176/251
# 38/38 [==============================] - 0s 137us/sample - loss: 0.2189
# Epoch 177/251
# 38/38 [==============================] - 0s 138us/sample - loss: 0.2184
# Epoch 178/251
# 38/38 [==============================] - 0s 134us/sample - loss: 0.2178
# Epoch 179/251
# 38/38 [==============================] - 0s 165us/sample - loss: 0.2173
# Epoch 180/251
# 38/38 [==============================] - 0s 146us/sample - loss: 0.2167
# Epoch 181/251
# 38/38 [==============================] - 0s 127us/sample - loss: 0.2162
# Epoch 182/251
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2157
# Epoch 183/251
# 38/38 [==============================] - 0s 137us/sample - loss: 0.2151
# Epoch 184/251
# 38/38 [==============================] - 0s 136us/sample - loss: 0.2146
# Epoch 185/251
# 38/38 [==============================] - 0s 151us/sample - loss: 0.2141
# Epoch 186/251
# 38/38 [==============================] - 0s 143us/sample - loss: 0.2136
# Epoch 187/251
# 38/38 [==============================] - 0s 130us/sample - loss: 0.2130
# Epoch 188/251
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2125
# Epoch 189/251
# 38/38 [==============================] - 0s 134us/sample - loss: 0.2120
# Epoch 190/251
# 38/38 [==============================] - 0s 158us/sample - loss: 0.2115
# Epoch 191/251
# 38/38 [==============================] - 0s 146us/sample - loss: 0.2110
# Epoch 192/251
# 38/38 [==============================] - 0s 131us/sample - loss: 0.2105
# Epoch 193/251
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2100
# Epoch 194/251
# 38/38 [==============================] - 0s 136us/sample - loss: 0.2095
# Epoch 195/251
# 38/38 [==============================] - 0s 130us/sample - loss: 0.2090
# Epoch 196/251
# 38/38 [==============================] - 0s 173us/sample - loss: 0.2085
# Epoch 197/251
# 38/38 [==============================] - 0s 139us/sample - loss: 0.2080
# Epoch 198/251
# 38/38 [==============================] - 0s 131us/sample - loss: 0.2075
# Epoch 199/251
# 38/38 [==============================] - 0s 140us/sample - loss: 0.2070
# Epoch 200/251
# 38/38 [==============================] - 0s 135us/sample - loss: 0.2065
# Epoch 201/251
# 38/38 [==============================] - 0s 149us/sample - loss: 0.2060
# Epoch 202/251
# 38/38 [==============================] - 0s 141us/sample - loss: 0.2055
# Epoch 203/251
# 38/38 [==============================] - 0s 139us/sample - loss: 0.2050
# Epoch 204/251
# 38/38 [==============================] - 0s 138us/sample - loss: 0.2045
# Epoch 205/251
# 38/38 [==============================] - 0s 134us/sample - loss: 0.2040
# Epoch 206/251
# 38/38 [==============================] - 0s 139us/sample - loss: 0.2035
# Epoch 207/251
# 38/38 [==============================] - 0s 162us/sample - loss: 0.2031
# Epoch 208/251
# 38/38 [==============================] - 0s 146us/sample - loss: 0.2026
# Epoch 209/251
# 38/38 [==============================] - 0s 138us/sample - loss: 0.2021
# Epoch 210/251
# 38/38 [==============================] - 0s 142us/sample - loss: 0.2016
# Epoch 211/251
# 38/38 [==============================] - 0s 137us/sample - loss: 0.2011
# Epoch 212/251
# 38/38 [==============================] - 0s 136us/sample - loss: 0.2007
# Epoch 213/251
# 38/38 [==============================] - 0s 164us/sample - loss: 0.2002
# Epoch 214/251
# 38/38 [==============================] - 0s 129us/sample - loss: 0.1997
# Epoch 215/251
# 38/38 [==============================] - 0s 142us/sample - loss: 0.1993
# Epoch 216/251
# 38/38 [==============================] - 0s 143us/sample - loss: 0.1988
# Epoch 217/251
# 38/38 [==============================] - 0s 140us/sample - loss: 0.1984
# Epoch 218/251
# 38/38 [==============================] - 0s 142us/sample - loss: 0.1979
# Epoch 219/251
# 38/38 [==============================] - 0s 153us/sample - loss: 0.1974
# Epoch 220/251
# 38/38 [==============================] - 0s 128us/sample - loss: 0.1970
# Epoch 221/251
# 38/38 [==============================] - 0s 142us/sample - loss: 0.1965
# Epoch 222/251
# 38/38 [==============================] - 0s 129us/sample - loss: 0.1961
# Epoch 223/251
# 38/38 [==============================] - 0s 158us/sample - loss: 0.1956
# Epoch 224/251
# 38/38 [==============================] - 0s 154us/sample - loss: 0.1952
# Epoch 225/251
# 38/38 [==============================] - 0s 131us/sample - loss: 0.1947
# Epoch 226/251
# 38/38 [==============================] - 0s 153us/sample - loss: 0.1943
# Epoch 227/251
# 38/38 [==============================] - 0s 139us/sample - loss: 0.1938
# Epoch 228/251
# 38/38 [==============================] - 0s 136us/sample - loss: 0.1934
# Epoch 229/251
# 38/38 [==============================] - 0s 160us/sample - loss: 0.1930
# Epoch 230/251
# 38/38 [==============================] - 0s 140us/sample - loss: 0.1925
# Epoch 231/251
# 38/38 [==============================] - 0s 134us/sample - loss: 0.1921
# Epoch 232/251
# 38/38 [==============================] - 0s 146us/sample - loss: 0.1917
# Epoch 233/251
# 38/38 [==============================] - 0s 134us/sample - loss: 0.1912
# Epoch 234/251
# 38/38 [==============================] - 0s 147us/sample - loss: 0.1908
# Epoch 235/251
# 38/38 [==============================] - 0s 147us/sample - loss: 0.1904
# Epoch 236/251
# 38/38 [==============================] - 0s 140us/sample - loss: 0.1899
# Epoch 237/251
# 38/38 [==============================] - 0s 149us/sample - loss: 0.1895
# Epoch 238/251
# 38/38 [==============================] - 0s 129us/sample - loss: 0.1891
# Epoch 239/251
# 38/38 [==============================] - 0s 138us/sample - loss: 0.1887
# Epoch 240/251
# 38/38 [==============================] - 0s 152us/sample - loss: 0.1883
# Epoch 241/251
# 38/38 [==============================] - 0s 140us/sample - loss: 0.1878
# Epoch 242/251
# 38/38 [==============================] - 0s 137us/sample - loss: 0.1874
# Epoch 243/251
# 38/38 [==============================] - 0s 144us/sample - loss: 0.1870
# Epoch 244/251
# 38/38 [==============================] - 0s 139us/sample - loss: 0.1866
# Epoch 245/251
# 38/38 [==============================] - 0s 148us/sample - loss: 0.1862
# Epoch 246/251
# 38/38 [==============================] - 0s 146us/sample - loss: 0.1858
# Epoch 247/251
# 38/38 [==============================] - 0s 131us/sample - loss: 0.1854
# Epoch 248/251
# 38/38 [==============================] - 0s 138us/sample - loss: 0.1850
# Epoch 249/251
# 38/38 [==============================] - 0s 145us/sample - loss: 0.1846
# Epoch 250/251
# 38/38 [==============================] - 0s 131us/sample - loss: 0.1842
# Epoch 251/251
# 38/38 [==============================] - 0s 160us/sample - loss: 0.1838
